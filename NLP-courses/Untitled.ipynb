# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline

# %%
x = np.arange(0,4,0.1)

# %%
plt.plot(x, np.sin(x), '-.' )
plt.plot(x, np.cos(x), '--g' )

# %%
x
# Out:
# array([0.])
