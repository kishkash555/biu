# %%
import run_lstm as rl

# %%
# !git log -2
# Out:
# commit 6cb1ef6bd3f1862541f96479ae8a9fe833d5ecf6 (HEAD -> diss-lstm-independent-tests)
# Author: kishaksh <kiskash555@gmail.com>
# Date:   Sun Oct 4 15:05:27 2020 +0300
#
#     adam
#
# commit def4d9bc916e61e8dacd78134767085ef46b40da
# Author: kishaksh <kiskash555@gmail.com>
# Date:   Sat Oct 3 22:26:20 2020 +0300
#
#     changed hidden size to 200

# %%
rl.train_lstm(
)
# Out:
# 0 69.7508983835578 30.456105832010508
# saving
# /home/siegman/miniconda3/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type ind_lstm. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /home/siegman/miniconda3/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type LSTM. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# 1 60.79093400388956 14.575894936919212
# 2 55.52561183273792 9.76103039085865
# 3 51.73795320093632 7.371495667845011
# 4 48.72776861488819 6.412616100162268
# 5 47.63553538173437 5.7887609004974365
# 6 46.48558945208788 5.4092299323529005
# 7 45.20632057636976 5.017658753320575
# 8 44.89696495234966 4.812299761921167
# 9 44.50652274489403 4.616384522989392
# 10 44.17825015634298 4.362829567864537
# ...

# %%
# !git log -2
# Out:
# commit a5b94a1b48b150e507963504313619a090d0f054 (HEAD -> diss-lstm-independent-tests)
# Author: kishaksh <kiskash555@gmail.com>
# Date:   Sun Oct 4 15:21:21 2020 +0300
#
#     lambda=0.05
#
# commit 6cb1ef6bd3f1862541f96479ae8a9fe833d5ecf6
# Author: kishaksh <kiskash555@gmail.com>
# Date:   Sun Oct 4 15:05:27 2020 +0300
#
#     adam

# %%
rl.train_lstm()
# Out:
# 0 64.07736858725548 16.544067032635212
# saving
# /home/siegman/miniconda3/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type ind_lstm. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /home/siegman/miniconda3/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type LSTM. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# 1 52.00441309809685 8.528147544711828
# 2 47.76012433320284 6.687669616192579
# 3 46.62998325377703 5.8056900426745415
# 4 46.13034611195326 5.416828805580735
# 5 45.83762637525797 5.028634320944548
# 6 45.67489464581013 4.766244225203991
# 7 45.48001030832529 4.55288946069777
# 8 45.29655695706606 4.400514768436551
# 9 45.15247865021229 4.216145662590861
# 10 45.29546047747135 4.128999883309007
# ...

# %%
# !git log -2
rl.train_lstm()
# Out:
# commit 5b89388129551b45d19b54f38b54de2ca0936974 (HEAD -> diss-lstm-independent-tests)
# Author: kishaksh <kiskash555@gmail.com>
# Date:   Sun Oct 4 15:28:30 2020 +0300
#
#     lr=0.01
#
# commit a5b94a1b48b150e507963504313619a090d0f054
# Author: kishaksh <kiskash555@gmail.com>
# Date:   Sun Oct 4 15:21:21 2020 +0300
#
#     lambda=0.05
# 0 68.92636699974537 19.309297550469637
# saving
# /home/siegman/miniconda3/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type ind_lstm. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /home/siegman/miniconda3/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type LSTM. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# 1 55.674304358661175 7.171332836151123
# 2 50.67016761004925 6.169406980276108
# ...

# %%
# !git log -2
rl.train_lstm()
# Out:
# commit a2301becab578602ee1469e4da66ac527994db82 (HEAD -> diss-lstm-independent-tests)
# Author: kishaksh <kiskash555@gmail.com>
# Date:   Sun Oct 4 15:38:41 2020 +0300
#
#     adagrad
#
# commit 5b89388129551b45d19b54f38b54de2ca0936974
# Author: kishaksh <kiskash555@gmail.com>
# Date:   Sun Oct 4 15:28:30 2020 +0300
#
#     lr=0.01
# 0 69.50291732698679 28.539637204259634
# saving
# /home/siegman/miniconda3/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type ind_lstm. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /home/siegman/miniconda3/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type LSTM. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# 1 65.62062633782625 27.00564980506897
# 2 64.24317899346352 24.986889004707336
# ...

# %%
# !git log -2
rl.train_lstm()
# Out:
# commit 51548fce0d520e32f716840468a5e88ea5a98060 (HEAD -> diss-lstm-independent-tests)
# Author: kishaksh <kiskash555@gmail.com>
# Date:   Sun Oct 4 15:47:19 2020 +0300
#
#     sparse adam
#
# commit a2301becab578602ee1469e4da66ac527994db82
# Author: kishaksh <kiskash555@gmail.com>
# Date:   Sun Oct 4 15:38:41 2020 +0300
#
#     adagrad
# 0 60.20239446312189 19.183805260807276
# saving
# /home/siegman/miniconda3/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type ind_lstm. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /home/siegman/miniconda3/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type LSTM. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# 1 47.83859870582819 9.070870112627745
# 2 44.4000855833292 6.729420393705368
# ...

# %%
# !git log -2
rl.train_lstm()
# Out:
# commit 8219dbff0439e386ebff5c0bd34a932e0ac69952 (HEAD -> diss-lstm-independent-tests)
# Author: kishaksh <kiskash555@gmail.com>
# Date:   Sun Oct 4 15:50:28 2020 +0300
#
#     lambda=0.001
#
# commit 51548fce0d520e32f716840468a5e88ea5a98060
# Author: kishaksh <kiskash555@gmail.com>
# Date:   Sun Oct 4 15:47:19 2020 +0300
#
#     sparse adam
# 0 52.86531876027584 12.68106547370553
# saving
# /home/siegman/miniconda3/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type ind_lstm. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /home/siegman/miniconda3/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type LSTM. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# 1 42.503741808235645 6.700485911220312
# 2 40.42258497327566 5.545844800770283
# ...

# %%
# !git log -2
rl.train_lstm()
# Out:
# commit 32e69710fff138cb47152a06c566098bdbb237cd (HEAD -> diss-lstm-independent-tests)
# Author: kishaksh <kiskash555@gmail.com>
# Date:   Sun Oct 4 16:04:08 2020 +0300
#
#     lambda=0.000, betas=0.7, 0.85
#
# commit 8219dbff0439e386ebff5c0bd34a932e0ac69952
# Author: kishaksh <kiskash555@gmail.com>
# Date:   Sun Oct 4 15:50:28 2020 +0300
#
#     lambda=0.001
# 0 60.27036337554455 14.631092432886362
# saving
# /home/siegman/miniconda3/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type ind_lstm. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /home/siegman/miniconda3/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type LSTM. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# 1 49.74950847029686 7.5805365815758705
# ...

# %%
# !git log -2
rl.train_lstm()
# Out:
# commit af92e3b8d97c5d923e49e4d3367a190038219954 (HEAD -> diss-lstm-independent-tests)
# Author: kishaksh <kiskash555@gmail.com>
# Date:   Sun Oct 4 16:40:58 2020 +0300
#
#     similarity penalty, back to sgd
#
# commit 32e69710fff138cb47152a06c566098bdbb237cd
# Author: kishaksh <kiskash555@gmail.com>
# Date:   Sun Oct 4 16:04:08 2020 +0300
#
#     lambda=0.000, betas=0.7, 0.85
# 0 68.34811861813068 20.656742613762617
# saving
# /home/siegman/miniconda3/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type ind_lstm. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /home/siegman/miniconda3/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type LSTM. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# 1 63.97580802440643 10.752516146749258
# ...

# %%
# !git log -2
rl.train_lstm()
# Out:
# commit 279d85f240fdef2555620ae0a5b59d9a7f2859fb (HEAD -> diss-lstm-independent-tests)
# Author: kishaksh <kiskash555@gmail.com>
# Date:   Sun Oct 4 16:58:05 2020 +0300
#
#     loss bug fix and lr change
#
# commit af92e3b8d97c5d923e49e4d3367a190038219954
# Author: kishaksh <kiskash555@gmail.com>
# Date:   Sun Oct 4 16:40:58 2020 +0300
#
#     similarity penalty, back to sgd
# 0 63.31920833140612 11.395313031971455
# saving
# /home/siegman/miniconda3/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type ind_lstm. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /home/siegman/miniconda3/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type LSTM. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# 1 49.51643044501543 6.520470838993788
# ...
