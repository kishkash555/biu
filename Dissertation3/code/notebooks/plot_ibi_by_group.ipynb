# %%
import get_db_data as gdd
import analyze_signal as anaz
import numpy as np
import matplotlib.pyplot as plt
from importlib import reload
reload(gdd);
reload(anaz);
from sqlalchemy.engine.result import RowProxy
from numpy.linalg import norm
import seaborn as sns

# %%
gdd.group_signal_sql

# %%
data = gdd.get_db_data()
pars = data.get_participants()

# %%
cohesions
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-f398ee63f6ab> in <module>
# ----> 1 cohesions
#
# NameError: name 'cohesions' is not defined

# %%
pars_tuples={}
for g, p in pars:
    pars_tuples[g] = pars_tuples.get(g,[])  + [p]
pars_tuples
# Out:
# {1001: [101, 102, 103],
#  1003: [108, 109],
#  1004: [110, 111, 112],
#  1005: [113, 114, 115],
#  1006: [116, 117, 118],
#  1007: [119, 120, 121],
#  1008: [122, 123, 124],
#  1009: [125, 126, 127],
#  1010: [128, 129, 130],
#  1011: [131, 132, 133],
#  1012: [134, 135, 136],
#  1013: [137, 138, 139],
#  1014: [140, 141, 142],
#  1015: [144, 145],
#  1016: [146, 147, 148],
#  1017: [149, 151],
#  1019: [155, 156, 157],
#  1020: [158, 159, 160],
#  1022: [164, 165, 166],
#  1023: [167, 168, 169],
#  1024: [170, 171, 172],
#  1025: [173, 174, 175],
#  1026: [176, 177, 178],
#  1027: [179, 180, 181],
#  1028: [182, 183, 184],
#  1029: [185, 186, 187],
#  1030: [188, 189, 190],
#  1031: [191, 192, 193],
#  1032: [194, 195, 196],
#  1033: [200, 201, 202],
#  1034: [203, 204, 205],
#  1035: [206, 207, 208],
#  1036: [209, 210, 211],
#  1037: [212, 213, 214],
#  1038: [215, 216, 217],
#  1039: [218, 219, 220],
#  1040: [221, 222, 223],
#  1041: [224, 225, 226],
#  1042: [227, 228, 229],
#  1043: [230, 231, 232],
#  1044: [233, 234, 235],
#  1045: [236, 237, 238],
#  1046: [239, 240, 241],
#  1047: [242, 243, 244],
#  1048: [245, 246, 247],
#  1049: [248, 249, 250],
#  1050: [251, 252, 253],
#  1051: [254, 255, 256]}

# %%
def plot_interaction(par_list,ax, cohesions):
    par_ids = [];
    for par_id, par_data in data.get_signal_by_series_type_and_interp_type(par_list,2,3):
        par_ids.append(str(par_id))
        ax.plot(par_data[:,0],par_data[:,1])
        i = int(np.random.rand()*200)
        ax.text(par_data[i,0],par_data[i,1],str(cohesions.get(par_id,"NA")))
    ax.legend(par_ids)

# %%
k=4; s=0
ptk = list(pars_tuples.keys())

# %%
print(s)
ax=plt.subplots(k,figsize=(9,6*k))
for i,g in enumerate(ptk[s:]):
    plot_interaction(pars_tuples[g],ax[1][i],cohes)
    if i == k-1:
        break
s = s + k
# Out:
# 0

# %%
s=4
print(s)
ax=plt.subplots(k,figsize=(9,6*k))
for i,g in enumerate(ptk[s:]):
    plot_interaction(pars_tuples[g],ax[1][i],cohes)
    if i == k-1:
        break
s = s + k
# Out:
# 4

# %%
print(s)
ax=plt.subplots(k,figsize=(9,6*k))
for i,g in enumerate(ptk[s:]):
    plot_interaction(pars_tuples[g],ax[1][i],cohes)
    if i == k-1:
        break
s = s + k
# Out:
# 8

# %%
print(s)
ax=plt.subplots(k,figsize=(9,6*k))
for i,g in enumerate(ptk[s:]):
    plot_interaction(pars_tuples[g],ax[1][i],cohes)
    if i == k-1:
        break
s = s + k
# Out:
# 12

# %%
print(s)
ax=plt.subplots(k,figsize=(9,6*k))
for i,g in enumerate(ptk[s:]):
    plot_interaction(pars_tuples[g],ax[1][i],cohes)
    if i == k-1:
        break
s = s + k
# Out:
# 16

# %%
print(s)
ax=plt.subplots(k,figsize=(9,6*k))
for i,g in enumerate(ptk[s:]):
    plot_interaction(pars_tuples[g],ax[1][i],cohes)
    if i == k-1:
        break
s = s + k
# Out:
# 20

# %%
print(s)
ax=plt.subplots(k,figsize=(9,6*k))
for i,g in enumerate(ptk[s:]):
    plot_interaction(pars_tuples[g],ax[1][i],cohes)
    if i == k-1:
        break
s = s + k
# Out:
# 24

# %%
s=28
print(s)
ax=plt.subplots(k,figsize=(9,6*k))
for i,g in enumerate(ptk[s:]):
    plot_interaction(pars_tuples[g],ax[1][i],cohes)
    if i == k-1:
        break
s = s + k
# Out:
# 28

# %%
print(s)
ax=plt.subplots(k,figsize=(9,6*k))
for i,g in enumerate(ptk[s:]):
    plot_interaction(pars_tuples[g],ax[1][i],cohes)
    if i == k-1:
        break
s = s + k
# Out:
# 32

# %%
pars_tuples={}
for g, p in pars:
    pars_tuples[g] = pars_tuples.get(g,[])  + [p]
pars_tuples
# Out:
# {1001: [101, 102, 103],
#  1003: [108, 109],
#  1004: [110, 111, 112],
#  1005: [113, 114, 115],
#  1006: [116, 117, 118],
#  1007: [119, 120, 121],
#  1008: [122, 123, 124],
#  1009: [125, 126, 127],
#  1010: [128, 129, 130],
#  1011: [131, 132, 133],
#  1012: [134, 135, 136],
#  1013: [137, 138, 139],
#  1014: [140, 141, 142],
#  1015: [144, 145],
#  1016: [146, 147, 148],
#  1017: [149, 151],
#  1019: [155, 156, 157],
#  1020: [158, 159, 160],
#  (1043, 232),
#  (1044, 233),
#  (1044, 234),
#  (1044, 235),
#  (1045, 236),
#  (1045, 237),
#  (1045, 238),
#  (1046, 239),
#  (1046, 240),
#  (1046, 241),
#  (1047, 242),
#  (1047, 243),
#  (1047, 244),
#  (1048, 245),
#  (1048, 246),
#  (1048, 247),
#  (1049, 248),
#  (1049, 249),
#  (1049, 250),
#  (1050, 251),
#  (1050, 252),
#  (1050, 253),
#  (1051, 254),
#  (1051, 255),
#  (1051, 256)]

# %%
cohes ={a[1]: str(a[2])[:4] for a in pars}

# %%
cohes
# Out:
# {101: '4.25',
#  102: '5.00',
#  103: '5.25',
#  108: '4.00',
#  109: '1.50',
#  110: '3.50',
#  111: '2.75',
#  112: '3.75',
#  116: '4.00',
#  117: '4.75',
#  118: '3.25',
#  119: '3.25',
#  120: '5.00',
#  121: '4.75',
#  122: '6.00',
#  123: '6.00',
#  124: '4.75',
#  125: '5.50',
#  126: '5.00',
#  127: '4.00',
#  128: '4.75',
#  129: '3.75',
#  130: '3.25',
#  131: '5.00',
#  132: '4.25',
#  133: '6.00',
#  134: '1.00',
#  135: '2.00',
#  136: '4.25',
#  137: '3.75',
#  138: '4.50',
#  139: '4.25',
#  140: '3.00',
#  141: '4.25',
#  142: '5.00',
#  144: '2.75',
#  145: '2.25',
#  146: '3.75',
#  147: '2.75',
#  148: '2.50',
#  149: '3.25',
#  151: '3.75',
#  155: '5.00',
#  156: '4.00',
#  157: '2.00',
#  158: '2.25',
#  159: '4.00',
#  160: '4.00',
#  164: '3.75',
#  165: '4.50',
#  166: '4.75',
#  167: '4.50',
#  168: '5.00',
#  169: '5.50',
#  170: '5.00',
#  171: '5.00',
#  172: '4.00',
#  173: '4.75',
#  174: '4.75',
#  175: '4.25',
#  176: '5.00',
#  177: '4.00',
#  178: '5.00',
#  179: '4.00',
#  180: '2.75',
#  181: '2.00',
#  182: '4.00',
#  183: '2.75',
#  185: '4.50',
#  186: '5.25',
#  187: '4.25',
#  188: '4.25',
#  189: '4.25',
#  190: '4.75',
#  191: '1.25',
#  192: '3.50',
#  193: '3.75',
#  194: '5.00',
#  195: '5.25',
#  196: '3.50',
#  200: '5.00',
#  201: '4.00',
#  202: '4.50',
#  203: '3.00',
#  204: '1.00',
#  205: '3.25',
#  206: '5.00',
#  207: '3.00',
#  208: '5.75',
#  209: '4.25',
#  210: '3.75',
#  211: '4.25',
#  212: '3.25',
#  213: '5.50',
#  214: '3.75',
#  215: '3.25',
#  216: '4.75',
#  217: '4.50',
#  218: '3.75',
#  219: '3.50',
#  220: '6.00',
#  221: '3.50',
#  222: '1.25',
#  223: '2.75',
#  224: '4.25',
#  225: '2.75',
#  226: '5.50',
#  227: '4.25',
#  228: '3.75',
#  229: '2.00',
#  230: '4.00',
#  231: '5.25',
#  232: '4.00',
#  233: '4.50',
#  234: '5.00',
#  235: '4.00',
#  236: '6.00',
#  237: '5.00',
#  238: '5.75',
#  239: '4.00',
#  240: '3.00',
#  241: '3.25',
#  242: '4.75',
#  243: '5.00',
#  244: '4.75',
#  245: '4.00',
#  246: '4.00',
#  247: '5.00',
#  248: '4.50',
#  249: '5.00',
#  250: '4.50',
#  251: '4.25',
#  252: '4.50',
#  253: '2.50',
#  254: '3.75',
#  255: '4.00',
#  256: '4.50'}
