# %%
midi_path = '../data/MIDI-Freestyle/Freestyle_1044.mid'

# %%
data = open(midi_path,'rb')

# %%
a=data.read()

# %%
a
# Out:
# b'MThd\x00\x00\x00\x06\x00\x00\x00\x01\x00`MTrk\x00\x00Eo\x00\xff\x03\x157 2-Marimba1 Classic\x00\x00\xffX\x04\x04\x02$\x08\x00\xffX\x04\x04\x02$\x08\x83J\x90-4\r\x80-@\n\x900L\x0c\x800@\r\x90- \r\x80-@$\x90->\n\x900E\x03\x80-@\x05\x800@\x00\x900$\x08\x90+\x1b\x05\x800@\x08\x80+@\x07\x90-!\r\x80-@\x1b\x900B\x05\x90-%\x08\x800@\x02\x90+8\x03\x80-@\n\x80+@\x11\x900B\x04\x90+2\t\x800@\x04\x80+@\x1d\x90+<\x02\x90-#\x00\x900U\x02\x80-@\x00\x90-:\t\x80+@\x03\x800@\x00\x80-@\x19\x90+!\r\x80+@#\x900L\x01\x90-D\x00\x90+D\x0c\x800@\x01\x80-@\x00\x80+@\x18\x90+%\x02\x90-3\x04\x900C\x06\x80+@\x02\x80-@\x05\x800@\x1b\x90-<\x01\x90+>\x02\x900P\x05\x80-@\x01\x90-\x1e\x05\x80+@\x01\x800@\x06\x80-@\x12\x90+!\x02\x90-8\x0b\x80+@\x01\x80-@\x1d\x90-B\x03\x90+6\x01\x900P\x05\x80-@\x00\x90-\x1d\x05\x800@\x00\x900\x14\x02\x80+@\x06\x80-@\x05\x800@\t\x90+\x19\x07\x90-K\x00\x900R\x06\x80+@\x07\x80-@\x00\x800@\x19\x90++\x00\x90-U\x04\x900H\x05\x80-@\x00\x90-)\x04\x80+@\x01\x800@\x00\x900\x1f\x08\x80-@\x05\x80
# ...

# %%
b=list(a)
b
# Out:
# [77,
#  84,
#  104,
#  100,
#  0,
#  0,
#  0,
#  6,
#  0,
#  0,
#  0,
#  1,
#  0,
#  96,
#  77,
#  84,
#  114,
#  107,
#  0,
#  0,
#  69,
#  111,
#  0,
#  255,
#  3,
#  21,
#  55,
#  32,
#  50,
#  45,
#  77,
#  97,
#  114,
#  105,
#  109,
#  98,
#  97,
#  49,
#  32,
#  67,
#  108,
#  97,
#  115,
#  115,
#  105,
#  99,
#  0,
#  0,
#  255,
#  88,
#  4,
#  4,
#  2,
#  36,
#  8,
#  0,
#  255,
#  88,
#  4,
#  4,
#  2,
#  36,
#  8,
#  131,
#  74,
#  144,
#  45,
#  52,
#  13,
#  128,
#  45,
#  64,
#  10,
#  144,
#  48,
#  76,
#  12,
#  128,
#  48,
#  64,
#  13,
#  144,
#  45,
#  32,
#  13,
#  128,
#  45,
#  64,
#  36,
#  144,
#  45,
#  62,
#  10,
#  144,
#  48,
#  69,
#  3,
#  128,
#  45,
#  64,
#  5,
#  128,
#  48,
#  64,
#  0,
#  144,
#  48,
#  36,
#  8,
#  144,
#  43,
#  27,
#  5,
#  128,
#  48,
#  64,
#  8,
#  128,
#  43,
#  64,
#  7,
#  144,
#  45,
#  33,
#  13,
#  128,
#  45,
#  64,
#  27,
#  144,
#  48,
#  66,
#  5,
#  144,
#  45,
#  37,
#  8,
#  128,
#  48,
#  64,
#  2,
#  144,
# ...

# %%
ord('\xFF'),ord('\x51'),ord('\x03')
# Out:
# (255, 81, 3)

# %%
[i for i in range(len(b)) if tuple(b[i:i+3])==(255,81,3)]
# Out:
# []

# %%
[i for i in range(len(b)) if b[i]==255]
# Out:
# [23, 48, 56, 17794]

# %%
b[23:27]
# Out:
# [255, 3, 21, 55]

# %%
b[48:51]
# Out:
# [255, 88, 4]

# %%
b[56:59]
# Out:
# [255, 88, 4]

# %%
b[17794:]
# Out:
# [255, 47, 0]
