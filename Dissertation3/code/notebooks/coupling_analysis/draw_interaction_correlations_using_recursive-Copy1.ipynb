# %%
import recursive as sv
import pickle
from os import path
import numpy as np
from scipy.stats import zscore
import pandas as pd
import matplotlib.pyplot as plt

# %%
from importlib import reload
reload(sv)
# Out:
# <module 'recursive' from '/home/siegman/packages/recursive_store/recursive.py'>

# %%
np.set_printoptions(precision=3, suppress=True)
np.set_string_function(None)

# %%
data_dir = path.join(*(['..']*3+['data','time_series_linear_interpolations']))
path.exists(data_dir)
# Out:
# True

# %% [markdown]
# ### Load `svdata`

# %%
with open(path.join(data_dir,'olap2.pickle'),'rb') as a:
    svdata = pickle.load(a)

# %%
np.set_string_function(lambda arr: '\n'.join(arr.__str__().split('\n')[:4]))

# %%
svdata.group_id
# Out:
# list_store (1001, 1003, 1004, 1005, 1006, 1007, 1008, 1009, 1010, 1011, 1012, 1013, 1014, 1015, 1016, 1017, 1019, 1020, 1022, 1023, 1024, 1025, 1026, 1027, 1028, 1029, 1030, 1031, 1032, 1033, 1034, 1035, 1036, 1037, 1038, 1039, 1040, 1041, 1042, 1043, 1044, 1045, 1046, 1047, 1048, 1049, 1050, 1051)

# %% [markdown]
# ### Extract the Freestyle session (which has index 3)

# %%
# work on all pairs and append to svdata
list_by_group = sv.list_store(svdata.sessions.sample(1)).hr.tolist()
len(list_by_group)
# Out:
# 48

# %%
list(map(lambda arr: (arr.mean(axis=0),arr.std(axis=0)),list_by_group[5].remez))
# Out:
# [([114.5     0.668], [60.477  0.068]),
#  ([114.5     0.747], [60.477  0.085]),
#  ([114.5     0.754], [60.477  0.093])]

# %% [markdown]
# ### Define a cross-correlation function
#
# the normalization is performed for each shift separately, to avoid giving the shifts an unfair start due to bias from normal

# %%
def correlate_signals(signal1, signal2,max_shift,output_shift=True):
    ls, ls2 = len(signal1),len(signal2)
    if ls !=  ls2:
        print(ls, len(signal2))
        min_len = min(ls,ls2)
        signal1=signal1[:min_len]
        signal2=signal2[:min_len]
        
    result_by_shift = \
        [np.dot(zscore(signal1[i:]),zscore(signal2[:-i]))/(ls-i) for i in range(max_shift+1,1,-1)] +\
        [np.dot(zscore(signal1),zscore(signal2))/ls] + \
        [np.dot(zscore(signal2[i:]),zscore(signal1[:-i]))/(ls-i) for i in range(1,max_shift+1)]
    return np.array(result_by_shift)

# %%
from itertools import combinations

# %% [markdown]
# ### Calculate the per-shift correlations

# %%
all_group_corr_by_shift= []
    
for gr_id,hr in zip(svdata.group_id.tolist(),list_by_group):
    participant_ids = hr.participant_id.tolist()
    signals = hr.remez.tolist()
    for (p1,s1),(p2,s2) in combinations(zip(participant_ids,signals),2):
        all_group_corr_by_shift.append({
            'group_id': gr_id, 
            'participants': (p1,p2), 
            'correls': correlate_signals(s1[:,1],s2[:,1],6)
        })
# Out:
# 523 527
# 527 523

# %%
all_group_corr_by_shift
# Out:
# [{'group_id': 1001,
#   'participants': (101, 102),
#   'correls': [-0.14  -0.132 -0.125 -0.12  -0.118 -0.118 -0.128 -0.154 -0.183 -0.212
#    -0.239 -0.264 -0.285]},
#  {'group_id': 1001,
#   'participants': (101, 103),
#   'correls': [0.236 0.29  0.34  0.385 0.424 0.456 0.494 0.495 0.486 0.469 0.445 0.415
#    0.381]},
#  {'group_id': 1001,
#   'participants': (102, 103),
#   'correls': [-0.084 -0.031  0.018  0.063  0.101  0.131  0.158  0.135  0.104  0.07
#     0.037  0.008 -0.016]},
#  {'group_id': 1003,
#   'participants': (108, 109),
#   'correls': [0.055 0.068 0.084 0.104 0.125 0.146 0.186 0.203 0.215 0.22  0.22  0.213
#    0.2  ]},
#  {'group_id': 1004,
#   'participants': (110, 111),
#   'correls': [-0.053 -0.034 -0.012  0.013  0.038  0.061  0.106  0.139  0.168  0.189
#     0.199  0.199  0.19 ]},
#  {'group_id': 1004,
#   'participants': (110, 112),
#   'correls': [0.057 0.076 0.098 0.123 0.149 0.176 0.222 0.238 0.248 0.25  0.245 0.234
#    0.217]},
#  {'group_id': 1004,
#   'participants': (111, 112),
#   'correls': [0.426 0.445 0.452 0.448 0.433 0.407 0.34  0.322 0.304 0.287 0.269 0.252
#    0.233]},
#  {'group_id': 1005,
#   'participants': (113, 114),
#   'correls': [-0.193 -0.17  -0.15  -0.133 -0.121 -0.113 -0.111 -0.116 -0.125 -0.136
#    -0.151 -0.166 -0.181]},
#  {'group_id': 1005,
#   'participants': (113, 115),
#   'correls': [0.349 0.353 0.355 0.355 0.352 0.345 0.322 0.308 0.291 0.273 0.255 0.238
#    0.222]},
#  {'group_id': 1005,
#   'participants': (114, 115),
#   'correls': [-0.086 -0.093 -0.103 -0.116 -0.132 -0.151 -0.193 -0.212 -0.23  -0.245
#    -0.258 -0.267 -0.271]},
#  {'group_id': 1006,
#   'participants': (116, 117),
#   'correls': [-0.201 -0.186 -0.17  -0.156 -0.142 -0.131 -0.113 -0.117 -0.12  -0.123
#    -0.126 -0.129 -0.131]},
#  {'group_id': 1006,
#   'participants': (116, 118),
#   'correls': [0.343 0.359 0.375 0.39  0.404 0.417 0.436 0.436 0.433 0.429 0.422 0.413
#    0.403]},
#  {'group_id': 1006,
#   'participants': (117, 118),
#   'correls': [0.163 0.149 0.138 0.13  0.128 0.13  0.152 0.165 0.181 0.199 0.216 0.233
#    0.246]},
#  {'group_id': 1007,
#   'participants': (119, 120),
#   'correls': [0.141 0.176 0.218 0.264 0.313 0.362 0.454 0.491 0.521 0.542 0.552 0.55
#    0.539]},
#  {'group_id': 1007,
#   'participants': (119, 121),
#   'correls': [0.37  0.384 0.394 0.398 0.398 0.393 0.374 0.363 0.352 0.343 0.335 0.331
#    0.33 ]},
#  {'group_id': 1007,
#   'participants': (120, 121),
#   'correls': [0.782 0.784 0.779 0.767 0.749 0.727 0.673 0.644 0.616 0.589 0.565 0.545
#    0.528]},
#  {'group_id': 1008,
#   'participants': (122, 123),
#   'correls': [0.116 0.182 0.249 0.314 0.372 0.42  0.473 0.475 0.459 0.426 0.378 0.317
#    0.247]},
#  {'group_id': 1008,
#   'participants': (122, 124),
#   'correls': [0.093 0.135 0.176 0.214 0.248 0.275 0.304 0.302 0.289 0.265 0.231 0.187
#    0.137]},
#  {'group_id': 1008,
#   'participants': (123, 124),
#   'correls': [0.118 0.176 0.231 0.281 0.326 0.362 0.405 0.413 0.41  0.396 0.373 0.342
#    0.306]},
#  {'group_id': 1009,
#   'participants': (125, 126),
#   'correls': [ 0.065  0.037  0.005 -0.029 -0.062 -0.092 -0.137 -0.147 -0.149 -0.139
#    -0.12  -0.092 -0.057]},
#  {'group_id': 1009,
#   'participants': (125, 127),
#   'correls': [-0.188 -0.176 -0.161 -0.145 -0.127 -0.107 -0.063 -0.045 -0.026 -0.006
#     0.014  0.033  0.049]},
#  {'group_id': 1009,
#   'participants': (126, 127),
#   'correls': [-0.047 -0.055 -0.059 -0.058 -0.053 -0.042 -0.009  0.013  0.036  0.061
#     0.086  0.11   0.132]},
#  {'group_id': 1010,
#   'participants': (128, 129),
#   'correls': [0.24  0.245 0.246 0.24  0.23  0.214 0.177 0.156 0.14  0.131 0.131 0.14
#    0.158]},
#  {'group_id': 1010,
#   'participants': (128, 130),
#   'correls': [0.065 0.07  0.079 0.091 0.106 0.123 0.16  0.175 0.191 0.207 0.222 0.236
#    0.249]},
#  {'group_id': 1010,
#   'participants': (129, 130),
#   'correls': [0.321 0.335 0.35  0.362 0.372 0.379 0.38  0.37  0.358 0.345 0.331 0.318
#    0.306]},
#  {'group_id': 1011,
#   'participants': (131, 132),
#   'correls': [0.112 0.164 0.221 0.282 0.343 0.403 0.504 0.542 0.568 0.582 0.583 0.572
#    0.549]},
#  {'group_id': 1011,
#   'participants': (131, 133),
#   'correls': [-0.108 -0.101 -0.086 -0.063 -0.033  0.002  0.077  0.112  0.145  0.172
#     0.193  0.209  0.219]},
#  {'group_id': 1011,
#   'participants': (132, 133),
#   'correls': [-0.159 -0.143 -0.122 -0.096 -0.067 -0.035  0.033  0.066  0.098  0.126
#     0.152  0.174  0.193]},
#  {'group_id': 1012,
#   'participants': (134, 135),
#   'correls': [ 0.146  0.12   0.084  0.041 -0.006 -0.054 -0.141 -0.171 -0.189 -0.196
#    -0.193 -0.178 -0.155]},
#  {'group_id': 1012,
#   'participants': (134, 136),
#   'correls': [-0.056 -0.034 -0.013  0.006  0.021  0.032  0.037  0.032  0.022  0.01
#    -0.004 -0.018 -0.031]},
#  {'group_id': 1012,
#   'participants': (135, 136),
#   'correls': [-0.181 -0.179 -0.173 -0.163 -0.15  -0.134 -0.103 -0.087 -0.075 -0.068
#    -0.066 -0.068 -0.076]},
#  {'group_id': 1013,
#   'participants': (137, 138),
#   'correls': [0.13  0.175 0.215 0.251 0.282 0.306 0.332 0.336 0.336 0.33  0.322 0.31
#    0.296]},
#  {'group_id': 1013,
#   'participants': (137, 139),
#   'correls': [-0.043 -0.004  0.038  0.081  0.125  0.169  0.249  0.281  0.307  0.326
#     0.338  0.342  0.338]},
#  {'group_id': 1013,
#   'participants': (138, 139),
#   'correls': [0.164 0.198 0.228 0.253 0.274 0.288 0.294 0.289 0.278 0.261 0.24  0.215
#    0.188]},
#  {'group_id': 1014,
#   'participants': (140, 141),
#   'correls': [0.05  0.061 0.082 0.112 0.148 0.189 0.272 0.305 0.331 0.347 0.352 0.344
#    0.325]},
#  {'group_id': 1014,
#   'participants': (140, 142),
#   'correls': [-0.011  0.015  0.048  0.087  0.131  0.177  0.264  0.298  0.324  0.337
#     0.339  0.327  0.305]},
#  {'group_id': 1014,
#   'participants': (141, 142),
#   'correls': [0.138 0.173 0.211 0.25  0.288 0.323 0.374 0.386 0.389 0.382 0.367 0.343
#    0.314]},
#  {'group_id': 1015,
#   'participants': (144, 145),
#   'correls': [0.246 0.246 0.246 0.246 0.247 0.25  0.259 0.267 0.276 0.287 0.298 0.31
#    0.322]},
#  {'group_id': 1016,
#   'participants': (146, 147),
#   'correls': [0.255 0.282 0.315 0.352 0.389 0.425 0.478 0.489 0.489 0.476 0.451 0.416
#    0.372]},
#  {'group_id': 1016,
#   'participants': (146, 148),
#   'correls': [-0.037 -0.023 -0.003  0.021  0.049  0.078  0.133  0.153  0.169  0.179
#     0.185  0.185  0.182]},
#  {'group_id': 1016,
#   'participants': (147, 148),
#   'correls': [-0.076 -0.076 -0.067 -0.05  -0.028 -0.001  0.058  0.085  0.109  0.13
#     0.147  0.16   0.166]},
#  {'group_id': 1017,
#   'participants': (149, 151),
#   'correls': [0.173 0.179 0.182 0.184 0.183 0.18  0.174 0.166 0.156 0.144 0.132 0.12
#    0.107]},
#  {'group_id': 1019,
#   'participants': (155, 156),
#   'correls': [0.157 0.143 0.135 0.134 0.139 0.149 0.183 0.198 0.212 0.225 0.234 0.238
#    0.237]},
#  {'group_id': 1019,
#   'participants': (155, 157),
#   'correls': [-0.35  -0.343 -0.335 -0.327 -0.321 -0.317 -0.319 -0.329 -0.339 -0.35
#    -0.361 -0.371 -0.379]},
#  {'group_id': 1019,
#   'participants': (156, 157),
#   'correls': [-0.145 -0.153 -0.16  -0.165 -0.169 -0.171 -0.173 -0.18  -0.185 -0.187
#    -0.187 -0.183 -0.177]},
#  {'group_id': 1020,
#   'participants': (158, 159),
#   'correls': [ 0.068  0.056  0.041  0.022  0.    -0.022 -0.068 -0.089 -0.108 -0.124
#    -0.137 -0.148 -0.157]},
#  {'group_id': 1020,
#   'participants': (158, 160),
#   'correls': [-0.089 -0.088 -0.086 -0.083 -0.082 -0.081 -0.085 -0.09  -0.097 -0.104
#    -0.112 -0.119 -0.124]},
#  {'group_id': 1020,
#   'participants': (159, 160),
#   'correls': [0.198 0.211 0.223 0.233 0.241 0.245 0.247 0.245 0.243 0.242 0.241 0.241
#    0.242]},
#  {'group_id': 1022,
#   'participants': (164, 165),
#   'correls': [-0.092 -0.097 -0.104 -0.111 -0.12  -0.13  -0.151 -0.162 -0.174 -0.187
#    -0.199 -0.211 -0.222]},
#  {'group_id': 1022,
#   'participants': (164, 166),
#   'correls': [0.344 0.349 0.351 0.35  0.346 0.339 0.316 0.3   0.283 0.264 0.245 0.225
#    0.207]},
#  {'group_id': 1022,
#   'participants': (165, 166),
#   'correls': [ 0.264  0.28   0.294  0.301  0.301  0.291  0.241  0.203  0.158  0.108
#     0.054  0.001 -0.048]},
#  {'group_id': 1023,
#   'participants': (167, 168),
#   'correls': [0.426 0.438 0.454 0.474 0.495 0.517 0.557 0.571 0.581 0.587 0.588 0.585
#    0.578]},
#  {'group_id': 1023,
#   'participants': (167, 169),
#   'correls': [0.453 0.487 0.521 0.555 0.588 0.618 0.664 0.677 0.682 0.68  0.669 0.649
#    0.621]},
#  {'group_id': 1023,
#   'participants': (168, 169),
#   'correls': [0.429 0.451 0.469 0.484 0.495 0.5   0.496 0.485 0.469 0.449 0.425 0.399
#    0.372]},
#  {'group_id': 1024,
#   'participants': (170, 171),
#   'correls': [0.211 0.21  0.211 0.216 0.224 0.237 0.271 0.291 0.311 0.329 0.345 0.357
#    0.364]},
#  {'group_id': 1024,
#   'participants': (170, 172),
#   'correls': [0.218 0.245 0.274 0.305 0.333 0.359 0.396 0.407 0.412 0.412 0.408 0.401
#    0.394]},
#  {'group_id': 1024,
#   'participants': (171, 172),
#   'correls': [0.36  0.351 0.337 0.318 0.294 0.266 0.204 0.173 0.143 0.115 0.09  0.067
#    0.047]},
#  {'group_id': 1025,
#   'participants': (173, 174),
#   'correls': [0.12  0.15  0.185 0.222 0.261 0.299 0.37  0.399 0.422 0.439 0.449 0.451
#    0.446]},
#  {'group_id': 1025,
#   'participants': (173, 175),
#   'correls': [0.184 0.211 0.236 0.26  0.284 0.307 0.352 0.373 0.394 0.413 0.43  0.444
#    0.453]},
#  {'group_id': 1025,
#   'participants': (174, 175),
#   'correls': [0.299 0.333 0.357 0.372 0.377 0.374 0.348 0.328 0.306 0.284 0.263 0.245
#    0.229]},
#  {'group_id': 1026,
#   'participants': (176, 177),
#   'correls': [0.166 0.197 0.223 0.244 0.257 0.26  0.235 0.21  0.178 0.142 0.103 0.065
#    0.03 ]},
#  {'group_id': 1026,
#   'participants': (176, 178),
#   'correls': [-0.157 -0.133 -0.104 -0.073 -0.041 -0.013  0.025  0.032  0.031  0.02
#     0.003 -0.019 -0.044]},
#  {'group_id': 1026,
#   'participants': (177, 178),
#   'correls': [0.017 0.018 0.017 0.015 0.013 0.01  0.006 0.005 0.005 0.006 0.007 0.009
#    0.012]},
#  {'group_id': 1027,
#   'participants': (179, 180),
#   'correls': [-0.248 -0.204 -0.156 -0.106 -0.056 -0.006  0.088  0.133  0.174  0.21
#     0.24   0.263  0.278]},
#  {'group_id': 1027,
#   'participants': (179, 181),
#   'correls': [-0.112 -0.098 -0.078 -0.052 -0.022  0.013  0.088  0.129  0.17   0.208
#     0.243  0.273  0.298]},
#  {'group_id': 1027,
#   'participants': (180, 181),
#   'correls': [0.118 0.141 0.165 0.189 0.213 0.233 0.262 0.266 0.266 0.26  0.249 0.234
#    0.215]},
#  {'group_id': 1028,
#   'participants': (182, 183),
#   'correls': [0.36  0.388 0.41  0.425 0.432 0.432 0.413 0.396 0.379 0.365 0.354 0.349
#    0.348]},
#  {'group_id': 1028,
#   'participants': (182, 184),
#   'correls': [-0.178 -0.178 -0.173 -0.166 -0.16  -0.157 -0.165 -0.174 -0.189 -0.207
#    -0.229 -0.253 -0.276]},
#  {'group_id': 1028,
#   'participants': (183, 184),
#   'correls': [-0.089 -0.097 -0.105 -0.113 -0.122 -0.13  -0.139 -0.138 -0.136 -0.132
#    -0.126 -0.119 -0.11 ]},
#  {'group_id': 1029,
#   'participants': (185, 186),
#   'correls': [0.306 0.337 0.359 0.372 0.379 0.379 0.374 0.379 0.386 0.398 0.412 0.43
#    0.449]},
#  {'group_id': 1029,
#   'participants': (185, 187),
#   'correls': [0.075 0.095 0.126 0.165 0.211 0.26  0.353 0.392 0.422 0.44  0.445 0.436
#    0.415]},
#  {'group_id': 1029,
#   'participants': (186, 187),
#   'correls': [0.286 0.293 0.296 0.296 0.293 0.289 0.277 0.271 0.267 0.265 0.264 0.265
#    0.267]},
#  {'group_id': 1030,
#   'participants': (188, 189),
#   'correls': [0.405 0.421 0.434 0.442 0.445 0.444 0.429 0.419 0.409 0.398 0.39  0.383
#    0.379]},
#  {'group_id': 1030,
#   'participants': (188, 190),
#   'correls': [0.028 0.06  0.095 0.129 0.161 0.189 0.228 0.236 0.238 0.236 0.23  0.223
#    0.216]},
#  {'group_id': 1030,
#   'participants': (189, 190),
#   'correls': [0.037 0.056 0.078 0.102 0.126 0.15  0.193 0.207 0.217 0.223 0.224 0.22
#    0.212]},
#  {'group_id': 1031,
#   'participants': (191, 192),
#   'correls': [-0.002  0.009  0.018  0.026  0.032  0.035  0.033  0.026  0.017  0.008
#    -0.002 -0.012 -0.02 ]},
#  {'group_id': 1031,
#   'participants': (191, 193),
#   'correls': [0.533 0.554 0.572 0.585 0.593 0.595 0.584 0.569 0.551 0.532 0.514 0.498
#    0.485]},
#  {'group_id': 1031,
#   'participants': (192, 193),
#   'correls': [0.269 0.277 0.283 0.288 0.289 0.288 0.274 0.261 0.246 0.23  0.213 0.198
#    0.186]},
#  {'group_id': 1032,
#   'participants': (194, 195),
#   'correls': [0.532 0.547 0.563 0.581 0.599 0.616 0.646 0.656 0.661 0.661 0.657 0.647
#    0.634]},
#  {'group_id': 1032,
#   'participants': (194, 196),
#   'correls': [0.279 0.281 0.283 0.287 0.291 0.297 0.309 0.313 0.317 0.319 0.318 0.314
#    0.306]},
#  {'group_id': 1032,
#   'participants': (195, 196),
#   'correls': [0.475 0.471 0.464 0.457 0.448 0.439 0.417 0.402 0.387 0.372 0.357 0.342
#    0.327]},
#  {'group_id': 1033,
#   'participants': (200, 201),
#   'correls': [0.064 0.101 0.138 0.175 0.21  0.243 0.298 0.318 0.332 0.341 0.345 0.343
#    0.338]},
#  {'group_id': 1033,
#   'participants': (200, 202),
#   'correls': [0.355 0.37  0.378 0.38  0.377 0.369 0.344 0.329 0.315 0.299 0.284 0.269
#    0.255]},
#  {'group_id': 1033,
#   'participants': (201, 202),
#   'correls': [0.454 0.451 0.445 0.436 0.426 0.414 0.387 0.373 0.358 0.345 0.332 0.32
#    0.309]},
#  {'group_id': 1034,
#   'participants': (203, 204),
#   'correls': [ 0.167  0.129  0.09   0.052  0.018 -0.01  -0.046 -0.055 -0.058 -0.056
#    -0.05  -0.042 -0.033]},
#  {'group_id': 1034,
#   'participants': (203, 205),
#   'correls': [-0.285 -0.268 -0.25  -0.23  -0.212 -0.194 -0.171 -0.171 -0.175 -0.186
#    -0.2   -0.218 -0.238]},
#  {'group_id': 1034,
#   'participants': (204, 205),
#   'correls': [0.12  0.102 0.083 0.065 0.049 0.037 0.026 0.028 0.036 0.05  0.07  0.094
#    0.122]},
#  {'group_id': 1035,
#   'participants': (206, 207),
#   'correls': [-0.493 -0.466 -0.436 -0.405 -0.375 -0.346 -0.301 -0.29  -0.284 -0.284
#    -0.289 -0.298 -0.309]},
#  {'group_id': 1035,
#   'participants': (206, 208),
#   'correls': [-0.204 -0.183 -0.164 -0.147 -0.135 -0.128 -0.136 -0.152 -0.175 -0.203
#    -0.237 -0.273 -0.31 ]},
#  {'group_id': 1035,
#   'participants': (207, 208),
#   'correls': [0.452 0.49  0.52  0.54  0.55  0.55  0.521 0.497 0.467 0.435 0.401 0.369
#    0.339]},
#  {'group_id': 1036,
#   'participants': (209, 210),
#   'correls': [0.217 0.258 0.298 0.337 0.373 0.405 0.455 0.472 0.483 0.487 0.485 0.478
#    0.465]},
#  {'group_id': 1036,
#   'participants': (209, 211),
#   'correls': [0.385 0.414 0.435 0.447 0.449 0.444 0.413 0.392 0.368 0.345 0.322 0.302
#    0.285]},
#  {'group_id': 1036,
#   'participants': (210, 211),
#   'correls': [0.188 0.207 0.224 0.241 0.254 0.265 0.277 0.279 0.275 0.267 0.252 0.234
#    0.212]},
#  {'group_id': 1037,
#   'participants': (212, 213),
#   'correls': [0.091 0.099 0.106 0.111 0.115 0.117 0.119 0.122 0.125 0.128 0.132 0.136
#    0.141]},
#  {'group_id': 1037,
#   'participants': (212, 214),
#   'correls': [0.041 0.053 0.063 0.072 0.079 0.084 0.092 0.09  0.089 0.09  0.093 0.099
#    0.107]},
#  {'group_id': 1037,
#   'participants': (213, 214),
#   'correls': [ 0.086  0.07   0.054  0.037  0.02   0.004 -0.025 -0.037 -0.047 -0.053
#    -0.055 -0.054 -0.05 ]},
#  {'group_id': 1038,
#   'participants': (215, 216),
#   'correls': [0.314 0.349 0.374 0.385 0.384 0.368 0.304 0.259 0.212 0.166 0.127 0.099
#    0.083]},
#  {'group_id': 1038,
#   'participants': (215, 217),
#   'correls': [0.114 0.13  0.155 0.188 0.227 0.269 0.344 0.371 0.388 0.394 0.387 0.37
#    0.341]},
#  {'group_id': 1038,
#   'participants': (216, 217),
#   'correls': [0.353 0.359 0.369 0.384 0.403 0.424 0.466 0.482 0.492 0.495 0.489 0.474
#    0.451]},
#  {'group_id': 1039,
#   'participants': (218, 219),
#   'correls': [-0.091 -0.059 -0.029 -0.001  0.022  0.039  0.055  0.055  0.049  0.038
#     0.024  0.007 -0.012]},
#  {'group_id': 1039,
#   'participants': (218, 220),
#   'correls': [ 0.185  0.159  0.135  0.113  0.094  0.077  0.05   0.042  0.034  0.026
#     0.017  0.007 -0.005]},
#  {'group_id': 1039,
#   'participants': (219, 220),
#   'correls': [-0.077 -0.101 -0.117 -0.125 -0.125 -0.118 -0.087 -0.076 -0.068 -0.064
#    -0.065 -0.072 -0.086]},
#  {'group_id': 1040,
#   'participants': (221, 222),
#   'correls': [0.252 0.251 0.251 0.25  0.249 0.245 0.232 0.223 0.212 0.199 0.184 0.167
#    0.149]},
#  {'group_id': 1040,
#   'participants': (221, 223),
#   'correls': [-0.259 -0.24  -0.218 -0.197 -0.178 -0.163 -0.149 -0.152 -0.162 -0.177
#    -0.196 -0.217 -0.237]},
#  {'group_id': 1040,
#   'participants': (222, 223),
#   'correls': [-0.138 -0.151 -0.163 -0.173 -0.182 -0.186 -0.184 -0.176 -0.165 -0.15
#    -0.133 -0.115 -0.097]},
#  {'group_id': 1041,
#   'participants': (224, 225),
#   'correls': [0.28  0.275 0.27  0.266 0.261 0.255 0.241 0.232 0.221 0.21  0.2   0.192
#    0.186]},
#  {'group_id': 1041,
#   'participants': (224, 226),
#   'correls': [-0.42  -0.388 -0.36  -0.336 -0.317 -0.306 -0.302 -0.309 -0.319 -0.327
#    -0.334 -0.337 -0.336]},
#  {'group_id': 1041,
#   'participants': (225, 226),
#   'correls': [-0.033 -0.063 -0.095 -0.127 -0.157 -0.184 -0.226 -0.241 -0.253 -0.261
#    -0.267 -0.269 -0.27 ]},
#  {'group_id': 1042,
#   'participants': (227, 228),
#   'correls': [-0.407 -0.405 -0.406 -0.411 -0.417 -0.426 -0.447 -0.457 -0.465 -0.47
#    -0.471 -0.468 -0.461]},
#  {'group_id': 1042,
#   'participants': (227, 229),
#   'correls': [-0.246 -0.24  -0.238 -0.24  -0.246 -0.255 -0.277 -0.285 -0.291 -0.295
#    -0.296 -0.294 -0.29 ]},
#  {'group_id': 1042,
#   'participants': (228, 229),
#   'correls': [0.323 0.355 0.38  0.396 0.399 0.392 0.346 0.312 0.273 0.231 0.19  0.152
#    0.121]},
#  {'group_id': 1043,
#   'participants': (230, 231),
#   'correls': [-0.01   0.013  0.038  0.062  0.084  0.103  0.126  0.128  0.123  0.112
#     0.096  0.075  0.052]},
#  {'group_id': 1043,
#   'participants': (230, 232),
#   'correls': [0.418 0.43  0.441 0.45  0.457 0.462 0.462 0.458 0.45  0.439 0.424 0.408
#    0.39 ]},
#  {'group_id': 1043,
#   'participants': (231, 232),
#   'correls': [-0.314 -0.333 -0.348 -0.357 -0.361 -0.361 -0.352 -0.345 -0.34  -0.335
#    -0.333 -0.332 -0.332]},
#  {'group_id': 1044,
#   'participants': (233, 234),
#   'correls': [-0.123 -0.106 -0.079 -0.044 -0.001  0.047  0.147  0.192  0.232  0.263
#     0.284  0.296  0.296]},
#  {'group_id': 1044,
#   'participants': (233, 235),
#   'correls': [0.227 0.273 0.317 0.357 0.39  0.414 0.428 0.418 0.396 0.363 0.321 0.273
#    0.221]},
#  {'group_id': 1044,
#   'participants': (234, 235),
#   'correls': [0.071 0.093 0.114 0.132 0.146 0.156 0.163 0.16  0.155 0.149 0.144 0.14
#    0.138]},
#  {'group_id': 1045,
#   'participants': (236, 237),
#   'correls': [0.206 0.223 0.237 0.246 0.25  0.248 0.225 0.205 0.181 0.156 0.13  0.106
#    0.086]},
#  {'group_id': 1045,
#   'participants': (236, 238),
#   'correls': [0.168 0.207 0.24  0.266 0.283 0.291 0.28  0.265 0.244 0.221 0.195 0.169
#    0.146]},
#  {'group_id': 1045,
#   'participants': (237, 238),
#   'correls': [0.149 0.166 0.185 0.204 0.222 0.237 0.257 0.262 0.263 0.262 0.258 0.253
#    0.247]},
#  {'group_id': 1046,
#   'participants': (239, 240),
#   'correls': [0.195 0.175 0.16  0.151 0.146 0.146 0.152 0.15  0.145 0.136 0.123 0.105
#    0.083]},
#  {'group_id': 1046,
#   'participants': (239, 241),
#   'correls': [0.303 0.313 0.319 0.317 0.309 0.293 0.241 0.211 0.18  0.15  0.126 0.109
#    0.101]},
#  {'group_id': 1046,
#   'participants': (240, 241),
#   'correls': [0.053 0.074 0.098 0.125 0.153 0.181 0.242 0.276 0.31  0.344 0.377 0.408
#    0.438]},
#  {'group_id': 1047,
#   'participants': (242, 243),
#   'correls': [-0.04   0.008  0.059  0.11   0.157  0.198  0.253  0.265  0.268  0.262
#     0.248  0.228  0.205]},
#  {'group_id': 1047,
#   'participants': (242, 244),
#   'correls': [0.097 0.123 0.148 0.172 0.194 0.211 0.231 0.232 0.227 0.215 0.198 0.175
#    0.149]},
#  {'group_id': 1047,
#   'participants': (243, 244),
#   'correls': [-0.181 -0.168 -0.154 -0.141 -0.13  -0.12  -0.109 -0.107 -0.107 -0.109
#    -0.113 -0.119 -0.126]},
#  {'group_id': 1048,
#   'participants': (245, 246),
#   'correls': [0.454 0.461 0.471 0.482 0.494 0.505 0.517 0.513 0.503 0.487 0.465 0.437
#    0.403]},
#  {'group_id': 1048,
#   'participants': (245, 247),
#   'correls': [-0.029 -0.007  0.014  0.034  0.051  0.062  0.062  0.049  0.03   0.005
#    -0.023 -0.054 -0.085]},
#  {'group_id': 1048,
#   'participants': (246, 247),
#   'correls': [-0.087 -0.069 -0.052 -0.038 -0.028 -0.021 -0.019 -0.028 -0.039 -0.051
#    -0.065 -0.079 -0.093]},
#  {'group_id': 1049,
#   'participants': (248, 249),
#   'correls': [0.134 0.142 0.146 0.145 0.139 0.129 0.1   0.088 0.078 0.075 0.077 0.086
#    0.103]},
#  {'group_id': 1049,
#   'participants': (248, 250),
#   'correls': [ 0.084  0.08   0.071  0.059  0.042  0.023 -0.022 -0.045 -0.068 -0.09
#    -0.111 -0.13  -0.148]},
#  {'group_id': 1049,
#   'participants': (249, 250),
#   'correls': [0.327 0.369 0.408 0.443 0.472 0.492 0.503 0.494 0.474 0.446 0.412 0.373
#    0.333]},
#  {'group_id': 1050,
#   'participants': (251, 252),
#   'correls': [0.27  0.274 0.276 0.276 0.274 0.271 0.261 0.254 0.246 0.237 0.227 0.216
#    0.204]},
#  {'group_id': 1050,
#   'participants': (251, 253),
#   'correls': [0.214 0.225 0.236 0.245 0.252 0.257 0.26  0.258 0.253 0.247 0.239 0.229
#    0.219]},
#  {'group_id': 1050,
#   'participants': (252, 253),
#   'correls': [-0.011  0.008  0.023  0.035  0.042  0.044  0.037  0.029  0.018  0.006
#    -0.007 -0.02  -0.033]},
#  {'group_id': 1051,
#   'participants': (254, 255),
#   'correls': [0.184 0.199 0.211 0.221 0.23  0.239 0.257 0.27  0.286 0.303 0.322 0.343
#    0.364]},
#  {'group_id': 1051,
#   'participants': (254, 256),
#   'correls': [0.01  0.038 0.068 0.099 0.132 0.163 0.217 0.241 0.261 0.277 0.291 0.303
#    0.312]},
#  {'group_id': 1051,
#   'participants': (255, 256),
#   'correls': [0.284 0.279 0.272 0.263 0.253 0.243 0.227 0.222 0.221 0.224 0.232 0.242
#    0.256]}]

# %%
df = pd.DataFrame(all_group_corr_by_shift)
df
# Out:
#      group_id participants                                            correls
# 0        1001   (101, 102)  [-0.13993890246894497, -0.13196561802570275, -...
# 1        1001   (101, 103)  [0.23607044923693116, 0.290141073719163, 0.340...
# 2        1001   (102, 103)  [-0.08420681410607093, -0.031474723171155926, ...
# 3        1003   (108, 109)  [0.05542077596788095, 0.06762035197626962, 0.0...
# 4        1004   (110, 111)  [-0.053430275460478426, -0.03439667098384155, ...
# ..        ...          ...                                                ...
# 133      1050   (251, 253)  [0.21379231571481996, 0.22520196960141853, 0.2...
# 134      1050   (252, 253)  [-0.011027198195804102, 0.00790241235191279, 0...
# 135      1051   (254, 255)  [0.18443795131139556, 0.19880779899093345, 0.2...
# 136      1051   (254, 256)  [0.0104662812800309, 0.037507537607036553, 0.0...
# 137      1051   (255, 256)  [0.2844870788225999, 0.27916787934438636, 0.27...
#
# [138 rows x 3 columns]

# %% [markdown]
# ### Show how the correlations with shift relate to the main correlation
#
# The graph shows a random-walk pattern starting from the no-shift state when progressing to the lateral shift states

# %%
plt.plot(np.vstack(df.correls.map(lambda v: v-v[6])).T);

# %% [markdown]
# ### The correlation histogram
#
# This is the "classic" historgram which we saw over and over

# %%
plt.hist(df.correls.map(lambda v: v[6]));

# %% [markdown]
# ### Check the relation of the extremes to the central correlation
#
# We see that there is strong coherence, i.e. correlations at the extremes are highly correlated with central correlations. Additionally, in this resolution, no central tendency can be observed

# %%
plt.hist2d(df.correls.map(lambda v: v[6]),df.correls.map(lambda v: v[0]));
plt.plot([-0.4, 0.6], [-0.4, 0.6],'b-')

# %%
plt.scatter(df.correls.map(lambda v: v[6]), df.correls.map(lambda v: v[0]))
plt.plot([-0.4, 0.6], [-0.4, 0.6],'b-')
ax = plt.gca()
plt.xlim(-0.8, 0.8)
plt.ylim(-0.8, 0.8)
ax.set_aspect(1)

# %%
plt.scatter(df.correls.map(lambda v: v[6]), df.correls.map(lambda v: v[-1]))
plt.plot([-0.4, 0.6], [-0.4, 0.6],'b-')
ax = plt.gca()
plt.xlim(-0.8, 0.8)
plt.ylim(-0.8, 0.8)
ax.set_aspect(1)

# %%
plt.hist2d(df.correls.map(lambda v: v[6]),df.correls.map(lambda v: v[12]));

# %%
all_group_corr_by_shift[0]['correls']
# Out:
# [-0.14  -0.132 -0.125 -0.12  -0.118 -0.118 -0.128 -0.154 -0.183 -0.212
#  -0.239 -0.264 -0.285]

# %% [markdown]
# ### Recreate the traingle plot

# %%
df['max_correl']=df.correls.map(np.max)
df['ptp_angular_dist'] = df.max_correl.map(lambda c: np.arccos(c)/np.pi)

# %% [raw]
# global yyy
# yyy =0
# def debug_agg(dists):
#     global yyy
#     yyy +=1
#     print("enter")
#     print(type(dists))
#     print(dists)
#     if yyy==4:
#         raise ValueError
#
# df.groupby('group_id').agg({'ptp_angular_dist':debug_agg},axis=1)

# %%
def traingle_2d_repr(dists):
    if len(dists)<3: 
        return np.nan
    x = min(dists)
    y = (sum(dists)-x)/(2*x)
    ret = np.array([x,y])
    return [x,y]

# %%
dist_points = df.groupby('group_id').agg({'ptp_angular_dist': traingle_2d_repr}).dropna()
dist_points
# Out:
#                                    ptp_angular_dist
# group_id
# 1001         [0.3352266190463019, 1.47206166533493]
# 1004       [0.3507211983911607, 1.2198192285257634]
# 1005       [0.3843317079204323, 1.3826323573894022]
# 1006      [0.35647247737535087, 1.3425352021670265]
# 1007       [0.21333445043266766, 1.602406438883338]
# 1008        [0.3425104547939118, 1.118401081287158]
# 1009        [0.4578990845316076, 1.052378556778532]
# 1010       [0.3760306454805831, 1.1181367188957547]
# 1011        [0.301989281827115, 1.4365333376622362]
# 1012       [0.4534913075880491, 1.1124439403909767]
# 1013       [0.3888532076059578, 1.0233106592868868]
# 1014       [0.3728071732593702, 1.0403588120041631]
# 1016      [0.33719232282647266, 1.3161069604282816]
# 1019      [0.42347469926674286, 1.3567232051077678]
# 1020      [0.42059950012005487, 1.1938564905604785]
# 1022       [0.3857856807199465, 1.2077717281870106]
# 1023        [0.260904007261578, 1.2131549958501815]
# 1024      [0.36496665690605357, 1.0467530738194408]
# 1025       [0.35028064712568374, 1.038965911581109]
# 1026      [0.41632325828416117, 1.1817438109743597]
# 1027       [0.4038131813801807, 1.0210409683704966]
# 1028      [0.35775501403575777, 1.5075888120633234]
# 1029      [0.35189683533123406, 1.0764953900926737]
# 1030      [0.35303758307500177, 1.2058389484261571]
# 1031      [0.29706540107912305, 1.5069581295044934]
# 1032       [0.27006967957420636, 1.368243149438068]
# 1033      [0.35007140123232444, 1.0911372644594333]
# 1034       [0.4466040624558552, 1.1371046217546434]
# 1035       [0.3145577710655403, 1.8002191801043843]
# 1036       [0.33809565607362463, 1.126529677399277]
# 1037       [0.4548835230468453, 1.0317554385999175]
# 1038      [0.33526883384694667, 1.1114478608659528]
# 1039      [0.44078415976114216, 1.1376854794909377]
# 1040      [0.41900322696551473, 1.2867308454225395]
# 1041       [0.4096737094647572, 1.3523234606479908]
# 1042      [0.36919115889600146, 1.6376489272544092]
# 1043       [0.3470278930179856, 1.5287229745032158]
# 1044      [0.35908956572032963, 1.1863941548113286]
# 1045       [0.4060101738540534, 1.0279103379436036]
# 1046       [0.3558372283188936, 1.1723474752448364]
# 1047       [0.41365997049402026, 1.159751804465663]
# 1048         [0.3271008704406784, 1.50765339116627]
# 1049       [0.3321033578245029, 1.3950800774540038]
# 1050        [0.4109196699701826, 1.097729622331127]
# 1051       [0.38128969426722437, 1.058426236046588]

# %%
plt.figure(figsize=(12,12))
plt.plot(*zip(*dist_points.ptp_angular_dist),'m.');

for gr_id, xy in dist_points.iterrows():
    xy=xy[0]
    plt.text(xy[0],xy[1]+0.01,str(gr_id),fontdict={'color':'magenta'})

# %%
print(svdata.sessions._data.__repr__()[:1000])
# Out:
# (list_store (dict_store {'session': 'BL', 'hr': list_store (dict_store {'participant_id': 101, 'spline_interp': [[0.874, 1.374, 1.874, 2.374, 2.874, 3.3..., 'signal_2hz': [[  3.5     0.928]
#  [  4.      0.951]
#  [  4.5     0.952]
#  ..., 'remez': [[  9.5     0.903]
#  [ 10.      0.907]
#  [ 10.5     0.912]
#  ...}
# , dict_store {'participant_id': 102, 'spline_interp': [[0.996, 1.496, 1.996, 2.496, 2.996, 3.4..., 'signal_2hz': [[  3.5     0.783]
#  [  4.      0.791]
#  [  4.5     0.78 ]
#  ..., 'remez': [[  9.5     0.771]
#  [ 10.      0.764]
#  [ 10.5     0.758]
#  ...}
# , dict_store {'participant_id': 103, 'spline_interp': [[0.97, 1.47, 1.97, 2.47, 2.969999999999..., 'signal_2hz': [[  3.5     0.686]
#  [  4.      0.698]
#  [  4.5     0.702]
#  ..., 'remez': [[  9.5     0.747]
#  [ 10.      0.755]
#  [ 10.5     0.762]
#  ...}
# )
# }
# , dict_store {'session': 'I', 'hr': list_store (dict_store {'participant_id': 101, 'spline_interp': [[1.35, 1.85, 2.35, 2.85, 3.35, 3.85, 4...., 'signal_2hz': [[  3.5     0.783]
#  [  4.      0.77

# %%
svdata._data[0]._data['group_id']

#svdata._data[0]._data['sessions'][3]._data['coupling']
# Out:
# 1001

# %%
if sv.list_store(svdata.sessions.sample(1)).coupling_2d is None:
    for gr in svdata._data:
        group_id = gr._data['group_id']
        fs_sess = gr._data['sessions']._data[1]._data
        try:
            fs_sess['coupling_2d'] = sv.dict_store(
               { 'remez': dist_points.loc[group_id].tolist()[0]})
        except KeyError:
            pass
    with open(path.join(data_dir,'olap2.pickle'),'wb') as a:
        pickle.dump(svdata,a)
else:
    print("coupling 2d already exists for Interaction session")
# Out:
# coupling 2d already exists for Interaction session

# %%
list_by_group[5].participant_ida

# %%
#dist_points.loc[1001,:]

# %%
svdata.coupling_2d
# Out:
# list_store (dict_store {'sessions': list_store (None, dict_store {'remez': [0.3352266190463019, 1.47206166533493]}
# , None, dict_store {'remez': [0.30865236229458465, 1.5412726626724513]}
# )
# }
# , None, dict_store {'sessions': list_store (None, dict_store {'remez': [0.3507211983911607, 1.2198192285257634]}
# , None, dict_store {'remez': [0.3893850693685441, 1.1577598096672328]}
# )
# }
# , dict_store {'sessions': list_store (None, dict_store {'remez': [0.3843317079204323, 1.3826323573894022]}
# , None, dict_store {'remez': [0.3424978648894185, 1.1037369607361516]}
# )
# }
# , dict_store {'sessions': list_store (None, dict_store {'remez': [0.35647247737535087, 1.3425352021670265]}
# , None, dict_store {'remez': [0.3945180155242411, 1.2437782157349861]}
# )
# }
# , dict_store {'sessions': list_store (None, dict_store {'remez': [0.21333445043266766, 1.602406438883338]}
# , None, dict_store {'remez': [0.2979630279257565, 1.1628519166274291]}
# )
# }
# , dict_store {'sessions': list_store (None, dict_store {'remez': [0.3425104547939118, 1.118401081287158]}
# , None, dict_store {'remez': [0.3915674530079116, 1.1189302316724807]}
# )
# }
# , dict_store {'sessions': list_store (None, dict_store {'remez': [0.4578990845316076, 1.052378556778532]}
# , None, dict_store {'remez': [0.3930193615969861, 1.294322822987879]}
# )
# }
# , dict_store {'sessions': list_store (None, dict_store {'remez': [0.3760306454805831, 1.1181367188957547]}
# , None, dict_store {'remez': [0.29278804249664886, 1.4555415137744683]}
# )
# }
# , dict_store {'sessions': list_store (None, dict_store {'remez': [0.301989281827115, 1.4365333376622362]}
# , None, dict_store {'remez': [0.3185629772561582, 1.0635898335619067]}
# )
# }
# , dict_store {'sessions': list_store (None, dict_store {'remez': [0.4534913075880491, 1.1124439403909767]}
# , None, dict_store {'remez': [0.39893728434650777, 1.176954052774006]}
# )
# }
# , dict_store {'sessions': list_store (None, dict_store {'remez': [0.3888532076059578, 1.0233106592868868]}
# , None, dict_store {'remez': [0.4162681354446837, 1.2219992050232475]}
# )
# }
# , dict_store {'sessions': list_store (None, dict_store {'remez': [0.3728071732593702, 1.0403588120041631]}
# , None, dict_store {'remez': [0.3699871670707527, 1.323087139852277]}
# )
# }
# , None, dict_store {'sessions': list_store (None, dict_store {'remez': [0.33719232282647266, 1.3161069604282816]}
# , None, dict_store {'remez': [0.4522486537248075, 1.1094872650374792]}
# )
# }
# , None, dict_store {'sessions': list_store (None, dict_store {'remez': [0.42347469926674286, 1.3567232051077678]}
# , None, dict_store {'remez': [0.2809548583232515, 1.273065641340394]}
# )
# }
# , dict_store {'sessions': list_store (None, dict_store {'remez': [0.42059950012005487, 1.1938564905604785]}
# , None, dict_store {'remez': [0.3308167999248434, 1.5337586141964188]}
# )
# }
# , dict_store {'sessions': list_store (None, dict_store {'remez': [0.3857856807199465, 1.2077717281870106]}
# , None, dict_store {'remez': [0.40419680085315657, 1.0516814368091714]}
# )
# }
# , dict_store {'sessions': list_store (None, dict_store {'remez': [0.260904007261578, 1.2131549958501815]}
# , None, None)
# }
# , dict_store {'sessions': list_store (None, dict_store {'remez': [0.36496665690605357, 1.0467530738194408]}
# , None, dict_store {'remez': [0.3477106582758595, 1.2827065126790764]}
# )
# }
# , dict_store {'sessions': list_store (None, dict_store {'remez': [0.35028064712568374, 1.038965911581109]}
# , None, dict_store {'remez': [0.3892527667120892, 1.1960744998899828]}
# )
# }
# , dict_store {'sessions': list_store (None, dict_store {'remez': [0.41632325828416117, 1.1817438109743597]}
# , None, dict_store {'remez': [0.2948224447756941, 1.1651451009468259]}
# )
# }
# , dict_store {'sessions': list_store (None, dict_store {'remez': [0.4038131813801807, 1.0210409683704966]}
# , None, dict_store {'remez': [0.2662609791574173, 1.6298716446543782]}
# )
# }
# , dict_store {'sessions': list_store (None, dict_store {'remez': [0.35775501403575777, 1.5075888120633234]}
# , None, dict_store {'remez': [0.3472018954665032, 1.4085986262851842]}
# )
# }
# , dict_store {'sessions': list_store (None, dict_store {'remez': [0.35189683533123406, 1.0764953900926737]}
# , None, dict_store {'remez': [0.4198623842650901, 1.115864101127419]}
# )
# }
# , dict_store {'sessions': list_store (None, dict_store {'remez': [0.35303758307500177, 1.2058389484261571]}
# , None, dict_store {'remez': [0.3695317575059872, 1.4211927289444082]}
# )
# }
# , dict_store {'sessions': list_store (None, dict_store {'remez': [0.29706540107912305, 1.5069581295044934]}
# , None, dict_store {'remez': [0.3328175295443733, 1.2155591055279984]}
# )
# }
# , dict_store {'sessions': list_store (None, dict_store {'remez': [0.27006967957420636, 1.368243149438068]}
# , None, dict_store {'remez': [0.33208128765519995, 1.2094851733936445]}
# )
# }
# , dict_store {'sessions': list_store (None, dict_store {'remez': [0.35007140123232444, 1.0911372644594333]}
# , None, dict_store {'remez': [0.34767081056749266, 1.0394731152705052]}
# )
# }
# , dict_store {'sessions': list_store (None, dict_store {'remez': [0.4466040624558552, 1.1371046217546434]}
# , None, dict_store {'remez': [0.4083810088830889, 1.3446450705626984]}
# )
# }
# , dict_store {'sessions': list_store (None, dict_store {'remez': [0.3145577710655403, 1.8002191801043843]}
# , None, dict_store {'remez': [0.3251957795484266, 1.143972600912142]}
# )
# }
# , dict_store {'sessions': list_store (None, dict_store {'remez': [0.33809565607362463, 1.126529677399277]}
# , None, dict_store {'remez': [0.29338478612385815, 1.2566146738340673]}
# )
# }
# , dict_store {'sessions': list_store (None, dict_store {'remez': [0.4548835230468453, 1.0317554385999175]}
# , None, dict_store {'remez': [0.29860106664940134, 1.6084757325869257]}
# )
# }
# , dict_store {'sessions': list_store (None, dict_store {'remez': [0.33526883384694667, 1.1114478608659528]}
# , None, dict_store {'remez': [0.3679504566725743, 1.0398570530611246]}
# )
# }
# , dict_store {'sessions': list_store (None, dict_store {'remez': [0.44078415976114216, 1.1376854794909377]}
# , None, dict_store {'remez': [0.37337810538862515, 1.2858490491098793]}
# )
# }
# , dict_store {'sessions': list_store (None, dict_store {'remez': [0.41900322696551473, 1.2867308454225395]}
# , None, dict_store {'remez': [0.36191454489500496, 1.30239009408975]}
# )
# }
# , dict_store {'sessions': list_store (None, dict_store {'remez': [0.4096737094647572, 1.3523234606479908]}
# , None, dict_store {'remez': [0.3242695314474899, 1.2164073785705674]}
# )
# }
# , dict_store {'sessions': list_store (None, dict_store {'remez': [0.36919115889600146, 1.6376489272544092]}
# , None, dict_store {'remez': [0.437451196968142, 1.102556909804223]}
# )
# }
# , dict_store {'sessions': list_store (None, dict_store {'remez': [0.3470278930179856, 1.5287229745032158]}
# , None, dict_store {'remez': [0.4119074957510476, 1.2431072148998228]}
# )
# }
# , dict_store {'sessions': list_store (None, dict_store {'remez': [0.35908956572032963, 1.1863941548113286]}
# , None, dict_store {'remez': [0.37346099242311126, 1.1197397811863425]}
# )
# }
# , dict_store {'sessions': list_store (None, dict_store {'remez': [0.4060101738540534, 1.0279103379436036]}
# , None, dict_store {'remez': [0.44553171757494375, 1.2092488285868854]}
# )
# }
# , dict_store {'sessions': list_store (None, dict_store {'remez': [0.3558372283188936, 1.1723474752448364]}
# , None, dict_store {'remez': [0.40062952586544126, 1.0565793997716868]}
# )
# }
# , dict_store {'sessions': list_store (None, dict_store {'remez': [0.41365997049402026, 1.159751804465663]}
# , None, dict_store {'remez': [0.40980835499724266, 1.235309461490013]}
# )
# }
# , dict_store {'sessions': list_store (None, dict_store {'remez': [0.3271008704406784, 1.50765339116627]}
# , None, dict_store {'remez': [0.4032673852996489, 1.1576767587332648]}
# )
# }
# , dict_store {'sessions': list_store (None, dict_store {'remez': [0.3321033578245029, 1.3950800774540038]}
# , None, dict_store {'remez': [0.28409843993164974, 1.7712982275786633]}
# )
# }
# , dict_store {'sessions': list_store (None, dict_store {'remez': [0.4109196699701826, 1.097729622331127]}
# , None, dict_store {'remez': [0.28776959070985336, 1.13944555059661]}
# )
# }
# , dict_store {'sessions': list_store (None, dict_store {'remez': [0.38128969426722437, 1.058426236046588]}
# , None, dict_store {'remez': [0.35093232382202344, 1.442302612723677]}
# )
# }
# )

# %%
svdata[5].sessions[3]

# %%
{} or None

# %%
sv.dict_store({}) or None

# %%
all([True,False])

# %%
all([])

# %%
any([])
