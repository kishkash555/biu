# %%
import music21 as m2
import glob
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %%
import sys
from os import path

code_path = path.abspath(path.join('..','..','diss3_code','midi'))
print(code_path, path.exists(code_path))

sys.path.append(code_path)
import midi_utils as mu
# Out:
# /home/siegman/Documents/Shahar/BarIlan/Dissertation3/code/diss3_code/midi True

# %%
from importlib import reload
reload(mu);

# %%
midi_paths = ['MIDI-Freestyle', 'MIDI-Interaction']
midi_paths = [path.abspath(path.join('..','..','..','data',p)) for p in midi_paths]
print([path.exists(p) for p in midi_paths])
midi_files = sum([glob.glob(path.join(mp,'*.mid')) for mp in midi_paths],[] )
# Out:
# [True, True]

# %%
midi_files[-5:]
# Out:
# ['/home/siegman/Documents/Shahar/BarIlan/Dissertation3/data/MIDI-Interaction/Interaction_1025.mid',
#  '/home/siegman/Documents/Shahar/BarIlan/Dissertation3/data/MIDI-Interaction/Interaction_1026.mid',
#  '/home/siegman/Documents/Shahar/BarIlan/Dissertation3/data/MIDI-Interaction/Interaction_1031.mid',
#  '/home/siegman/Documents/Shahar/BarIlan/Dissertation3/data/MIDI-Interaction/Interaction_1027.mid',
#  '/home/siegman/Documents/Shahar/BarIlan/Dissertation3/data/MIDI-Interaction/Interaction_1046.mid']

# %%
timing_df = pd.read_excel('timings_from_abelton.xlsx', engine="openpyxl")
cols =list(timing_df.columns)
cols[1]='group'
timing_df.columns=cols
timing_df
# Out:
#                type  group  minute  seconds  hundreds   total
# 0   non-predictable   1003       4       49        25  289.25
# 1   non-predictable   1005       4       49        48  289.48
# 2   non-predictable   1008       4       49        59  289.59
# 3   non-predictable   1010       4       58        30  298.30
# 4   non-predictable   1012       4       49        37  289.37
# 5   non-predictable   1014       5        0        56  300.56
# 6   non-predictable   1016       5        7        85  307.85
# 7   non-predictable   1018       6        4        45  364.45
# 8   non-predictable   1020       4       49        10  289.10
# 9   non-predictable   1022       4       49        15  289.15
# 10  non-predictable   1024       4       50         1  290.01
# 11  non-predictable   1026       4       48        86  288.86
# 12  non-predictable   1028       3       23        36  203.36
# 13  non-predictable   1030       4       50        53  290.53
# 14  non-predictable   1032       4       48        97  288.97
# 15  non-predictable   1034       4       49         3  289.03
# 16  non-predictable   1036       4       49        25  289.25
# 17        freestyle   1003       5       20        34  320.34
# 18        freestyle   1005       4       15         3  255.03
# 19        freestyle   1008       4       18         0  258.00
# 20        freestyle   1010       4       24        85  264.85
# 21        freestyle   1012       4       29        91  269.91
# 22        freestyle   1014       5        2        12  302.12
# 23        freestyle   1016       5       40        30  340.30
# 24        freestyle   1018       4       28        51  268.51
# 25        freestyle   1020       4       26        13  266.13
# 26        freestyle   1022       4        7         6  247.06
# 27        freestyle   1024       4        8        55  248.55
# 28        freestyle   1026       4        9        64  249.64
# 29        freestyle   1028       4        7        29  247.29
# 30        freestyle   1030       4       12        43  252.43
# 31        freestyle   1032       5       37        24  337.24
# 32        freestyle   1034       5        9        88  309.88
# 33        freestyle   1036       5       36        85  336.85

# %%
dir(mu)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'drummer_events',
#  'event_filter',
#  'get_drumbeat_ticks_for_midi',
#  'get_files_for_session',
#  'glob',
#  'group_events',
#  'load_midi',
#  'm2',
#  'mc',
#  'np',
#  'path',
#  'pd',
#  'plt',
#  'populate_music_dictionary',
#  'sns']

# %%
all_ticks = mu.populate_music_dictionary(midi_files)
# Out:
# ('1009', 'Freestyle', 43)
# ('1009', 'Freestyle', 45)
# ('1009', 'Freestyle', 48)
# ('1025', 'Freestyle', 43)
# ('1025', 'Freestyle', 48)
# ('1025', 'Freestyle', 45)
# ('1021', 'Freestyle', 45)
# ('1021', 'Freestyle', 48)
# ('1021', 'Freestyle', 43)
# ('1018', 'Freestyle', 43)
# ('1018', 'Freestyle', 48)
# ('1018', 'Freestyle', 45)
# ('1008', 'Freestyle', 48)
# ('1008', 'Freestyle', 45)
# ('1008', 'Freestyle', 43)
# ('1048', 'Freestyle', 45)
# ('1048', 'Freestyle', 43)
# ('1048', 'Freestyle', 48)
# ('1026', 'Freestyle', 43)
# ('1026', 'Freestyle', 45)
# ('1026', 'Freestyle', 48)
# ('1024', 'Freestyle', 43)
# ('1024', 'Freestyle', 48)
# ('1024', 'Freestyle', 45)
# ('1023', 'Freestyle', 48)
# ('1023', 'Freestyle', 43)
# ('1023', 'Freestyle', 45)
# ('1033', 'Freestyle', 45)
# ('1033', 'Freestyle', 43)
# ('1033', 'Freestyle', 48)
# ('1045', 'Freestyle', 48)
# ('1045', 'Freestyle', 43)
# ('1045', 'Freestyle', 45)
# ('1034', 'Freestyle', 45)
# ('1034', 'Freestyle', 48)
# ('1034', 'Freestyle', 43)
# ('1046', 'Freestyle', 48)
# ('1046', 'Freestyle', 45)
# ('1046', 'Freestyle', 43)
# ('1035', 'Freestyle', 45)
# ('1035', 'Freestyle', 43)
# ('1035', 'Freestyle', 48)
# ('1030', 'Freestyle', 43)
# ('1030', 'Freestyle', 48)
# ('1030', 'Freestyle', 45)
# ('1031', 'Freestyle', 43)
# ('1031', 'Freestyle', 48)
# ('1031', 'Freestyle', 45)
# ('1032', 'Freestyle', 43)
# ('1032', 'Freestyle', 48)
# ('1032', 'Freestyle', 45)
# ('1014', 'Freestyle', 45)
# ('1014', 'Freestyle', 43)
# ('1014', 'Freestyle', 48)
# ('1002', 'Freestyle', 48)
# ('1002', 'Freestyle', 43)
# ('1002', 'Freestyle', 45)
# ('1016', 'Freestyle', 45)
# ('1016', 'Freestyle', 43)
# ('1016', 'Freestyle', 48)
# ('1042', 'Freestyle', 45)
# ('1042', 'Freestyle', 48)
# ('1042', 'Freestyle', 43)
# ('1013', 'Freestyle', 45)
# ('1013', 'Freestyle', 48)
# ('1013', 'Freestyle', 43)
# ('1029', 'Freestyle', 45)
# ('1029', 'Freestyle', 48)
# ('1029', 'Freestyle', 43)
# ('1047', 'Freestyle', 43)
# ('1047', 'Freestyle', 45)
# ('1047', 'Freestyle', 48)
# ('1050', 'Freestyle', 48)
# ('1050', 'Freestyle', 43)
# ('1050', 'Freestyle', 45)
# ('1049', 'Freestyle', 45)
# ('1049', 'Freestyle', 48)
# ('1049', 'Freestyle', 43)
# ('1003', 'Freestyle', 45)
# ('1003', 'Freestyle', 48)
# ('1003', 'Freestyle', 43)
# ('1004', 'Freestyle', 48)
# ('1004', 'Freestyle', 45)
# ('1004', 'Freestyle', 43)
# ('1038', 'Freestyle', 45)
# ('1038', 'Freestyle', 43)
# ('1038', 'Freestyle', 48)
# ('1022', 'Freestyle', 43)
# ('1022', 'Freestyle', 48)
# ('1022', 'Freestyle', 45)
# ('1015', 'Freestyle', 48)
# ('1015', 'Freestyle', 43)
# ('1015', 'Freestyle', 45)
# ('1007', 'Freestyle', 48)
# ('1007', 'Freestyle', 45)
# ('1007', 'Freestyle', 43)
# ('1051', 'Freestyle', 45)
# ('1051', 'Freestyle', 43)
# ('1051', 'Freestyle', 48)
# ('1044', 'Freestyle', 45)
# ('1044', 'Freestyle', 48)
# ('1044', 'Freestyle', 43)
# ('1041', 'Freestyle', 43)
# ('1041', 'Freestyle', 45)
# ('1041', 'Freestyle', 48)
# ('1019', 'Freestyle', 43)
# ('1019', 'Freestyle', 45)
# ('1019', 'Freestyle', 48)
# ('1010', 'Freestyle', 45)
# ('1010', 'Freestyle', 43)
# ('1010', 'Freestyle', 48)
# ('1027', 'Freestyle', 43)
# ('1027', 'Freestyle', 45)
# ('1027', 'Freestyle', 48)
# ('1040', 'Freestyle', 45)
# ('1040', 'Freestyle', 48)
# ('1040', 'Freestyle', 43)
# ('1011', 'Freestyle', 45)
# ('1011', 'Freestyle', 48)
# ('1011', 'Freestyle', 43)
# ('1039', 'Freestyle', 48)
# ('1039', 'Freestyle', 45)
# ('1039', 'Freestyle', 43)
# ('1001', 'Freestyle', 43)
# ('1001', 'Freestyle', 45)
# ('1001', 'Freestyle', 48)
# ('1005', 'Freestyle', 45)
# ('1005', 'Freestyle', 48)
# ('1005', 'Freestyle', 43)
# ('1012', 'Freestyle', 45)
# ('1012', 'Freestyle', 48)
# ('1012', 'Freestyle', 43)
# ('1017', 'Freestyle', 43)
# ('1017', 'Freestyle', 48)
# ('1017', 'Freestyle', 45)
# ('1006', 'Freestyle', 45)
# ('1006', 'Freestyle', 48)
# ('1006', 'Freestyle', 43)
# ('1028', 'Freestyle', 45)
# ('1028', 'Freestyle', 48)
# ('1028', 'Freestyle', 43)
# ('1037', 'Freestyle', 45)
# ('1037', 'Freestyle', 43)
# ('1037', 'Freestyle', 48)
# ('1036', 'Freestyle', 48)
# ('1036', 'Freestyle', 45)
# ('1036', 'Freestyle', 43)
# ('1043', 'Freestyle', 45)
# ('1043', 'Freestyle', 48)
# ('1043', 'Freestyle', 43)
# ('1020', 'Freestyle', 43)
# ('1020', 'Freestyle', 48)
# ('1020', 'Freestyle', 45)
# ('1039', 'Interaction', 43)
# ('1039', 'Interaction', 48)
# ('1039', 'Interaction', 45)
# ('1011', 'Interaction', 43)
# ('1011', 'Interaction', 45)
# ('1011', 'Interaction', 48)
# ('1045', 'Interaction', 43)
# ('1045', 'Interaction', 45)
# ('1045', 'Interaction', 48)
# ('1034', 'Interaction', 43)
# ('1034', 'Interaction', 48)
# ('1034', 'Interaction', 45)
# ('1017', 'Interaction', 45)
# ('1017', 'Interaction', 48)
# ('1017', 'Interaction', 43)
# ('1006', 'Interaction', 43)
# ('1006', 'Interaction', 48)
# ('1006', 'Interaction', 45)
# ('1036', 'Interaction', 48)
# ('1036', 'Interaction', 43)
# ('1036', 'Interaction', 45)
# ('1018', 'Interaction', 45)
# ('1018', 'Interaction', 48)
# ('1018', 'Interaction', 43)
# ('1033', 'Interaction', 48)
# ('1033', 'Interaction', 45)
# ('1033', 'Interaction', 43)
# ('1024', 'Interaction', 48)
# ('1024', 'Interaction', 45)
# ('1024', 'Interaction', 43)
# ('1032', 'Interaction', 43)
# ('1032', 'Interaction', 48)
# ('1032', 'Interaction', 45)
# ('1028', 'Interaction', 43)
# ('1028', 'Interaction', 48)
# ('1028', 'Interaction', 45)
# ('1050', 'Interaction', 45)
# ('1050', 'Interaction', 48)
# ('1050', 'Interaction', 43)
# ('1051', 'Interaction', 45)
# ('1051', 'Interaction', 48)
# ('1051', 'Interaction', 43)
# ('1016', 'Interaction', 45)
# ('1016', 'Interaction', 43)
# ('1016', 'Interaction', 48)
# ('1009', 'Interaction', 45)
# ('1009', 'Interaction', 48)
# ('1009', 'Interaction', 43)
# ('1020', 'Interaction', 43)
# ('1020', 'Interaction', 45)
# ('1020', 'Interaction', 48)
# ('1048', 'Interaction', 48)
# ('1048', 'Interaction', 45)
# ('1048', 'Interaction', 43)
# ('1041', 'Interaction', 43)
# ('1041', 'Interaction', 45)
# ('1041', 'Interaction', 48)
# ('1035', 'Interaction', 43)
# ('1035', 'Interaction', 48)
# ('1035', 'Interaction', 45)
# ('1030', 'Interaction', 48)
# ('1030', 'Interaction', 43)
# ('1030', 'Interaction', 45)
# ('1005', 'Interaction', 43)
# ('1005', 'Interaction', 48)
# ('1005', 'Interaction', 45)
# ('1005', 'Interaction', 51)
# ('1022', 'Interaction', 45)
# ('1022', 'Interaction', 43)
# ('1022', 'Interaction', 48)
# ('1044', 'Interaction', 45)
# ('1044', 'Interaction', 43)
# ('1044', 'Interaction', 48)
# ('1010', 'Interaction', 48)
# ('1010', 'Interaction', 43)
# ('1010', 'Interaction', 45)
# ('1013', 'Interaction', 45)
# ('1013', 'Interaction', 43)
# ('1013', 'Interaction', 48)
# ('1012', 'Interaction', 45)
# ('1012', 'Interaction', 48)
# ('1012', 'Interaction', 43)
# ('1040', 'Interaction', 43)
# ('1040', 'Interaction', 45)
# ('1040', 'Interaction', 48)
# ('1003', 'Interaction', 43)
# ('1003', 'Interaction', 45)
# ('1003', 'Interaction', 48)
# ('1001', 'Interaction', 43)
# ('1001', 'Interaction', 45)
# ('1001', 'Interaction', 48)
# ('1015', 'Interaction', 48)
# ('1015', 'Interaction', 43)
# ('1015', 'Interaction', 45)
# ('1042', 'Interaction', 48)
# ('1042', 'Interaction', 45)
# ('1042', 'Interaction', 43)
# ('1021', 'Interaction', 43)
# ('1021', 'Interaction', 48)
# ('1021', 'Interaction', 45)
# ('1047', 'Interaction', 48)
# ('1047', 'Interaction', 43)
# ('1047', 'Interaction', 45)
# ('1008', 'Interaction', 43)
# ('1008', 'Interaction', 45)
# ('1008', 'Interaction', 48)
# ('1014', 'Interaction', 45)
# ('1014', 'Interaction', 43)
# ('1014', 'Interaction', 48)
# ('1019', 'Interaction', 45)
# ('1019', 'Interaction', 48)
# ('1019', 'Interaction', 43)
# ('1038', 'Interaction', 45)
# ('1038', 'Interaction', 48)
# ('1038', 'Interaction', 43)
# ('1049', 'Interaction', 48)
# ('1049', 'Interaction', 45)
# ('1049', 'Interaction', 43)
# ('1004', 'Interaction', 48)
# ('1004', 'Interaction', 45)
# ('1004', 'Interaction', 43)
# ('1023', 'Interaction', 48)
# ('1023', 'Interaction', 43)
# ('1023', 'Interaction', 45)
# ('1043', 'Interaction', 45)
# ('1043', 'Interaction', 43)
# ('1043', 'Interaction', 48)
# ('1007', 'Interaction', 48)
# ('1007', 'Interaction', 43)
# ('1007', 'Interaction', 45)
# ('1037', 'Interaction', 43)
# ('1037', 'Interaction', 48)
# ('1037', 'Interaction', 45)
# ('1025', 'Interaction', 43)
# ('1025', 'Interaction', 45)
# ('1025', 'Interaction', 48)
# ('1026', 'Interaction', 43)
# ('1026', 'Interaction', 48)
# ('1026', 'Interaction', 45)
# ('1031', 'Interaction', 48)
# ('1031', 'Interaction', 43)
# ('1031', 'Interaction', 45)
# ('1027', 'Interaction', 43)
# ('1027', 'Interaction', 48)
# ('1027', 'Interaction', 45)
# ('1046', 'Interaction', 45)
# ('1046', 'Interaction', 48)
# ('1046', 'Interaction', 43)

# %%
len(all_ticks)
# Out:
# 301

# %%
def get_last_beat(all_ticks, gr,session):
    parti = [43,45,48]
    last = [all_ticks.get((str(gr),session,p),[-1,-1])[-1]  for p in parti]
    return len(last),max(last)

# %%
ses = {'non-predictable': 'Interaction', 'freestyle':'Freestyle'}
timing_df['last_beat']= timing_df.apply(lambda r: get_last_beat(all_ticks, r.group, ses[r.type.strip()]),axis=1)

# %%
timing_df
# Out:
#                type  group  minute  seconds  hundreds   total   last_beat
# 0   non-predictable   1003       4       49        25  289.25  (3, 51187)
# 1   non-predictable   1005       4       49        48  289.48  (3, 51247)
# 2   non-predictable   1008       4       49        59  289.59  (3, 58899)
# 3   non-predictable   1010       4       58        30  298.30  (3, 53276)
# 4   non-predictable   1012       4       49        37  289.37  (3, 51217)
# 5   non-predictable   1014       5        0        56  300.56  (3, 53882)
# 6   non-predictable   1016       5        7        85  307.85  (3, 57996)
# 7   non-predictable   1018       6        4        45  364.45  (3, 69057)
# 8   non-predictable   1020       4       49        10  289.10  (3, 51162)
# 9   non-predictable   1022       4       49        15  289.15  (3, 51178)
# 10  non-predictable   1024       4       50         1  290.01  (3, 51371)
# 11  non-predictable   1026       4       48        86  288.86  (3, 51104)
# 12  non-predictable   1028       3       23        36  203.36  (3, 36763)
# 13  non-predictable   1030       4       50        53  290.53  (3, 51509)
# 14  non-predictable   1032       4       48        97  288.97  (3, 51135)
# 15  non-predictable   1034       4       49         3  289.03  (3, 51184)
# 16  non-predictable   1036       4       49        25  289.25  (3, 51180)
# 17        freestyle   1003       5       20        34  320.34  (3, 30255)
# 18        freestyle   1005       4       15         3  255.03  (3, 32630)
# 19        freestyle   1008       4       18         0  258.00  (3, 33007)
# 20        freestyle   1010       4       24        85  264.85  (3, 33894)
# 21        freestyle   1012       4       29        91  269.91  (3, 34041)
# 22        freestyle   1014       5        2        12  302.12  (3, 38653)
# 23        freestyle   1016       5       40        30  340.30  (3, 32813)
# 24        freestyle   1018       4       28        51  268.51  (3, 34355)
# 25        freestyle   1020       4       26        13  266.13  (3, 34071)
# 26        freestyle   1022       4        7         6  247.06  (3, 31613)
# 27        freestyle   1024       4        8        55  248.55  (3, 31799)
# 28        freestyle   1026       4        9        64  249.64  (3, 31966)
# 29        freestyle   1028       4        7        29  247.29  (3, 31632)
# 30        freestyle   1030       4       12        43  252.43  (3, 32305)
# 31        freestyle   1032       5       37        24  337.24  (3, 32425)
# 32        freestyle   1034       5        9        88  309.88  (3, 31980)
# 33        freestyle   1036       5       36        85  336.85  (3, 32371)

# %%
timing_df['last_beat1'] = timing_df.last_beat.map(lambda x: x[1])
timing_df
# Out:
#                type  group  minute  seconds  hundreds   total   last_beat  \
# 0   non-predictable   1003       4       49        25  289.25  (3, 51187)
# 1   non-predictable   1005       4       49        48  289.48  (3, 51247)
# 2   non-predictable   1008       4       49        59  289.59  (3, 58899)
# 3   non-predictable   1010       4       58        30  298.30  (3, 53276)
# 4   non-predictable   1012       4       49        37  289.37  (3, 51217)
# 5   non-predictable   1014       5        0        56  300.56  (3, 53882)
# 6   non-predictable   1016       5        7        85  307.85  (3, 57996)
# 7   non-predictable   1018       6        4        45  364.45  (3, 69057)
# 8   non-predictable   1020       4       49        10  289.10  (3, 51162)
# 9   non-predictable   1022       4       49        15  289.15  (3, 51178)
# 10  non-predictable   1024       4       50         1  290.01  (3, 51371)
# 11  non-predictable   1026       4       48        86  288.86  (3, 51104)
# 12  non-predictable   1028       3       23        36  203.36  (3, 36763)
# 13  non-predictable   1030       4       50        53  290.53  (3, 51509)
# 14  non-predictable   1032       4       48        97  288.97  (3, 51135)
# 15  non-predictable   1034       4       49         3  289.03  (3, 51184)
# 16  non-predictable   1036       4       49        25  289.25  (3, 51180)
# 17        freestyle   1003       5       20        34  320.34  (3, 30255)
# 18        freestyle   1005       4       15         3  255.03  (3, 32630)
# 19        freestyle   1008       4       18         0  258.00  (3, 33007)
# 20        freestyle   1010       4       24        85  264.85  (3, 33894)
# 21        freestyle   1012       4       29        91  269.91  (3, 34041)
# 22        freestyle   1014       5        2        12  302.12  (3, 38653)
# 23        freestyle   1016       5       40        30  340.30  (3, 32813)
# 24        freestyle   1018       4       28        51  268.51  (3, 34355)
# 25        freestyle   1020       4       26        13  266.13  (3, 34071)
# 26        freestyle   1022       4        7         6  247.06  (3, 31613)
# 27        freestyle   1024       4        8        55  248.55  (3, 31799)
# 28        freestyle   1026       4        9        64  249.64  (3, 31966)
# 29        freestyle   1028       4        7        29  247.29  (3, 31632)
# 30        freestyle   1030       4       12        43  252.43  (3, 32305)
# 31        freestyle   1032       5       37        24  337.24  (3, 32425)
# 32        freestyle   1034       5        9        88  309.88  (3, 31980)
# 33        freestyle   1036       5       36        85  336.85  (3, 32371)
#
#     last_beat1
# 0        51187
# 1        51247
# 2        58899
# 3        53276
# 4        51217
# 5        53882
# 6        57996
# 7        69057
# 8        51162
# 9        51178
# 10       51371
# 11       51104
# 12       36763
# 13       51509
# 14       51135
# 15       51184
# 16       51180
# 17       30255
# 18       32630
# 19       33007
# 20       33894
# 21       34041
# 22       38653
# 23       32813
# 24       34355
# 25       34071
# 26       31613
# 27       31799
# 28       31966
# 29       31632
# 30       32305
# 31       32425
# 32       31980
# 33       32371

# %%
sns.scatterplot(data=timing_df, x='last_beat1', y='total', hue='type')
for row in timing_df.itertuples():
    plt.text( row.last_beat1, row.total+3, row.group)

# %%
[k for k in all_ticks.keys() if k[0]=='1028']
# Out:
# [('1028', 'Freestyle', 45),
#  ('1028', 'Freestyle', 48),
#  ('1028', 'Freestyle', 43),
#  ('1028', 'Interaction', 43),
#  ('1028', 'Interaction', 48),
#  ('1028', 'Interaction', 45)]

# %%
timing_df['ratio']=timing_df.last_beat1/timing_df.total

# %%
timing_df[(timing_df.type=='non-predictable') & (~timing_df.group.isin([1008]))]
# Out:
#                type  group  minute  seconds  hundreds   total   last_beat  \
# 0   non-predictable   1003       4       49        25  289.25  (3, 51187)
# 1   non-predictable   1005       4       49        48  289.48  (3, 51247)
# 3   non-predictable   1010       4       58        30  298.30  (3, 53276)
# 4   non-predictable   1012       4       49        37  289.37  (3, 51217)
# 5   non-predictable   1014       5        0        56  300.56  (3, 53882)
# 6   non-predictable   1016       5        7        85  307.85  (3, 57996)
# 7   non-predictable   1018       6        4        45  364.45  (3, 69057)
# 8   non-predictable   1020       4       49        10  289.10  (3, 51162)
# 9   non-predictable   1022       4       49        15  289.15  (3, 51178)
# 10  non-predictable   1024       4       50         1  290.01  (3, 51371)
# 11  non-predictable   1026       4       48        86  288.86  (3, 51104)
# 12  non-predictable   1028       3       23        36  203.36  (3, 36763)
# 13  non-predictable   1030       4       50        53  290.53  (3, 51509)
# 14  non-predictable   1032       4       48        97  288.97  (3, 51135)
# 15  non-predictable   1034       4       49         3  289.03  (3, 51184)
# 16  non-predictable   1036       4       49        25  289.25  (3, 51180)
#
#     last_beat1       ratio
# 0        51187  176.964564
# 1        51247  177.031228
# 3        53276  178.598726
# 4        51217  176.994851
# 5        53882  179.272026
# 6        57996  188.390450
# 7        69057  189.482782
# 8        51162  176.969907
# 9        51178  176.994639
# 10       51371  177.135271
# 11       51104  176.916153
# 12       36763  180.777931
# 13       51509  177.293223
# 14       51135  176.956085
# 15       51184  177.088884
# 16       51180  176.940363

# %%
#(timing_df.type=='non-predictable'),
timing_df.group[2]==1008
# Out:
# True
