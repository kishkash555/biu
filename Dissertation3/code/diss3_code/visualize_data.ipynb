# %%
import sparse_ae as sae
import time
from importlib import reload

import loader

import matplotlib.pyplot as plt
reload(loader)
reload(sae)
# Out:
# <module 'sparse_ae' from '/home/siegman/Documents/Shahar/BarIlan/Dissertation3/code/sparse_ae.py'>

# %%
data = loader.loader(None)
gen= data.generator(training=True)

# %%
k=0
for i, (id,x,y) in enumerate(gen,1):
    plt.plot(x.numpy()[0,0,:])
    if not i % 10:
        break

# %%
k=0
plt.figure(figsize=(8,5))
for i, (id,x,y) in enumerate(gen,1):
    plt.plot(x.numpy()[0,0,:])
    if not i % 5:
        break

# %%
k=0
plt.figure(figsize=(8,5))
for i, (id,x,y) in enumerate(gen,1):
    plt.plot(x.numpy()[0,0,:])
    if not i % 5:
        break

# %%
k=0
plt.figure(figsize=(8,5))
for i, (id,x,y) in enumerate(gen,1):
    plt.plot(x.numpy()[0,0,:])
    if not i % 5:
        break

# %%
k=0
plt.figure(figsize=(8,5))
for i, (id,x,y) in enumerate(gen,1):
    plt.plot(x.numpy()[0,0,:])
    if not i % 5:
        break

# %%
k=0
plt.figure(figsize=(8,5))
for i, (id,x,y) in enumerate(gen,1):
    plt.plot(x.numpy()[0,0,:])
    if not i % 5:
        break

# %%
k=0
plt.figure(figsize=(8,5))
for i, (id,x,y) in enumerate(gen,1):
    plt.plot(x.numpy()[0,0,:])
    if not i % 5:
        break

# %%
k=0
plt.figure(figsize=(8,5))
for i, (id,x,y) in enumerate(gen,1):
    plt.plot(x.numpy()[0,0,:])
    if not i % 5:
        break

# %%
k=0
plt.figure(figsize=(8,5))
for i, (id,x,y) in enumerate(gen,1):
    plt.plot(x.numpy()[0,0,:])
    if not i % 5:
        break

# %%
k=0
plt.figure(figsize=(8,5))
for i, (id,x,y) in enumerate(gen,1):
    plt.plot(x.numpy()[0,0,:])
    if not i % 5:
        break

# %%
k=0
plt.figure(figsize=(8,5))
for i, (id,x,y) in enumerate(gen,1):
    plt.plot(x.numpy()[0,0,:])
    if not i % 5:
        break

# %%
k=0
plt.figure(figsize=(8,5))
for i, (id,x,y) in enumerate(gen,1):
    plt.plot(x.numpy()[0,0,:])
    if not i % 5:
        break

# %%
k=0
plt.figure(figsize=(8,5))
for i, (id,x,y) in enumerate(gen,1):
    plt.plot(x.numpy()[0,0,:])
    if not i % 5:
        break
