# %%
import get_db_data as gdd

import matplotlib.pyplot as plt

# %%
data = gdd.get_db_data()

# %%
#gdd.get_signal_by_series_type_and_interp_type(group_id,series_type,interp_type)
g = data.get_signal_by_series_type_and_interp_type([123],3,3)

# %%
sig = next(g)[1]
plt.plot(sig[:,1])

# %%
g
# Out:
# <generator object get_db_data.get_signal_by_series_type_and_interp_type at 0x7ff700a6e6d0>

# %%
sig
# Out:
# array([[  3.5    ,   0.86525],
#        [  4.     ,   0.85033],
#        [  4.5    ,   0.8384 ],
#        ...,
#        [314.     ,   0.93377],
#        [314.5    ,   0.92892],
#        [315.     ,   0.91451]])

# %%
next(g)
