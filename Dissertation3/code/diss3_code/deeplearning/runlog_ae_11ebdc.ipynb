# %%
import sparse_ae as sae
import time
from importlib import reload

import loader

import matplotlib.pyplot as plt
reload(loader)
reload(sae)
# Out:
# <module 'sparse_ae' from '/home/siegman/Documents/Shahar/BarIlan/Dissertation3/code/sparse_ae.py'>

# %%
# !git status
# Out:
# On branch diss-dl-experiments1
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
#
# 	Untitled.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git log -1
# Out:
# commit 11ebdc57c78e27ac4ee738dadaf099cdd150c0a0 (HEAD -> diss-dl-experiments1)
# Author: kishaksh <kiskash555@gmail.com>
# Date:   Tue Jul 7 14:39:17 2020 +0300
#
#     normalized each vector separately to zero mean

# %%
print(time.asctime())
try:
    dn = sae.ann_model()
    sae.train(dn, 1200)
except:
    pass
finally:
    print(time.asctime())
# Out:
# Tue Jul  7 14:40:34 2020
# Entering Epoch:  0
#
# ======> epoch: 0/1200, Loss:7.4110, l: 941
# Entering Epoch:  1
#
# ======> epoch: 1/1200, Loss:7.3820, l: 941
# Entering Epoch:  2
#
# ======> epoch: 2/1200, Loss:7.3366, l: 941
# Entering Epoch:  3
#
# ======> epoch: 3/1200, Loss:7.2580, l: 941
# Entering Epoch:  4
#
# ======> epoch: 4/1200, Loss:7.1067, l: 941
# Entering Epoch:  5
#
# ======> epoch: 5/1200, Loss:6.8837, l: 941
# Entering Epoch:  6
#
# ======> epoch: 6/1200, Loss:6.5394, l: 941
# Entering Epoch:  7
#
# ======> epoch: 7/1200, Loss:6.1383, l: 941
# Entering Epoch:  8
#
# ======> epoch: 8/1200, Loss:5.5944, l: 941
# Entering Epoch:  9
#
# ======> epoch: 9/1200, Loss:5.0465, l: 941
# Entering Epoch:  10
#
# ======> epoch: 10/1200, Loss:4.5338, l: 941
# Entering Epoch:  11
#
# ======> epoch: 11/1200, Loss:4.0468, l: 941
# Entering Epoch:  12
#
# ======> epoch: 12/1200, Loss:3.6325, l: 941
# Entering Epoch:  13
#
# ======> epoch: 13/1200, Loss:3.3184, l: 941
# Entering Epoch:  14
#
# ======> epoch: 14/1200, Loss:3.0317, l: 941
# Entering Epoch:  15
#
# ======> epoch: 15/1200, Loss:2.8051, l: 941
# Entering Epoch:  16
#
# ======> epoch: 16/1200, Loss:2.4707, l: 941
# Entering Epoch:  17
#
# ======> epoch: 17/1200, Loss:2.2598, l: 941
# Entering Epoch:  18
#
# ======> epoch: 18/1200, Loss:2.0579, l: 941
# Entering Epoch:  19
#
# ======> epoch: 19/1200, Loss:1.9367, l: 941
# Entering Epoch:  20
#
# ======> epoch: 20/1200, Loss:1.6901, l: 941
# Entering Epoch:  21
#
# ======> epoch: 21/1200, Loss:1.5649, l: 941
# Entering Epoch:  22
#
# ======> epoch: 22/1200, Loss:1.4397, l: 941
# Entering Epoch:  23
#
# ======> epoch: 23/1200, Loss:1.3894, l: 941
# Entering Epoch:  24
#
# ======> epoch: 24/1200, Loss:1.2200, l: 941
# Entering Epoch:  25
#
# ======> epoch: 25/1200, Loss:1.1830, l: 941
# Entering Epoch:  26
#
# ======> epoch: 26/1200, Loss:1.0756, l: 941
# Entering Epoch:  27
#
# ======> epoch: 27/1200, Loss:0.9765, l: 941
# Entering Epoch:  28
#
# ======> epoch: 28/1200, Loss:0.8540, l: 941
# Entering Epoch:  29
#
# ======> epoch: 29/1200, Loss:0.8695, l: 941
# Entering Epoch:  30
#
# ======> epoch: 30/1200, Loss:0.8536, l: 941
# Entering Epoch:  31
#
# ======> epoch: 31/1200, Loss:0.7850, l: 941
# Entering Epoch:  32
#
# ======> epoch: 32/1200, Loss:0.6466, l: 941
# Entering Epoch:  33
#
# ======> epoch: 33/1200, Loss:0.5880, l: 941
# Entering Epoch:  34
#
# ======> epoch: 34/1200, Loss:0.5710, l: 941
# Entering Epoch:  35
#
# ======> epoch: 35/1200, Loss:0.6695, l: 941
# Entering Epoch:  36
#
# ======> epoch: 36/1200, Loss:0.5262, l: 941
# Entering Epoch:  37
#
# ======> epoch: 37/1200, Loss:0.5351, l: 941
# Entering Epoch:  38
#
# ======> epoch: 38/1200, Loss:0.4565, l: 941
# Entering Epoch:  39
#
# ======> epoch: 39/1200, Loss:0.4807, l: 941
# Entering Epoch:  40
#
# ======> epoch: 40/1200, Loss:0.4212, l: 941
# Entering Epoch:  41
#
# ======> epoch: 41/1200, Loss:0.3590, l: 941
# Entering Epoch:  42
#
# ======> epoch: 42/1200, Loss:0.4086, l: 941
# Entering Epoch:  43
#
# ======> epoch: 43/1200, Loss:0.4072, l: 941
# Entering Epoch:  44
#
# ======> epoch: 44/1200, Loss:0.3357, l: 941
# Entering Epoch:  45
#
# ======> epoch: 45/1200, Loss:0.3351, l: 941
# Entering Epoch:  46
#
# ======> epoch: 46/1200, Loss:0.2605, l: 941
# Entering Epoch:  47
#
# ======> epoch: 47/1200, Loss:0.3033, l: 941
# Entering Epoch:  48
#
# ======> epoch: 48/1200, Loss:0.2797, l: 941
# Entering Epoch:  49
#
# ======> epoch: 49/1200, Loss:0.2987, l: 941
# Entering Epoch:  50
#
# ======> epoch: 50/1200, Loss:0.2621, l: 941
# Entering Epoch:  51
#
# ======> epoch: 51/1200, Loss:0.2556, l: 941
# Entering Epoch:  52
#
# ======> epoch: 52/1200, Loss:0.2141, l: 941
# Entering Epoch:  53
#
# ======> epoch: 53/1200, Loss:0.3103, l: 941
# Entering Epoch:  54
#
# ======> epoch: 54/1200, Loss:0.2091, l: 941
# Entering Epoch:  55
#
# ======> epoch: 55/1200, Loss:0.1612, l: 941
# Entering Epoch:  56
#
# ======> epoch: 56/1200, Loss:0.1946, l: 941
# Entering Epoch:  57
#
# ======> epoch: 57/1200, Loss:0.2490, l: 941
# Entering Epoch:  58
#
# ======> epoch: 58/1200, Loss:0.1719, l: 941
# Entering Epoch:  59
#
# ======> epoch: 59/1200, Loss:0.1782, l: 941
# Entering Epoch:  60
#
# ======> epoch: 60/1200, Loss:0.2263, l: 941
# Entering Epoch:  61
#
# ======> epoch: 61/1200, Loss:0.1867, l: 941
# Entering Epoch:  62
#
# ======> epoch: 62/1200, Loss:0.1180, l: 941
# Entering Epoch:  63
#
# ======> epoch: 63/1200, Loss:0.1498, l: 941
# Entering Epoch:  64
#
# ======> epoch: 64/1200, Loss:0.1914, l: 941
# Entering Epoch:  65
#
# ======> epoch: 65/1200, Loss:0.2016, l: 941
# Entering Epoch:  66
#
# ======> epoch: 66/1200, Loss:0.1079, l: 941
# Entering Epoch:  67
#
# ======> epoch: 67/1200, Loss:0.1105, l: 941
# Entering Epoch:  68
#
# ======> epoch: 68/1200, Loss:0.1603, l: 941
# Entering Epoch:  69
#
# ======> epoch: 69/1200, Loss:0.2295, l: 941
# Entering Epoch:  70
#
# ======> epoch: 70/1200, Loss:0.0882, l: 941
# Entering Epoch:  71
#
# ======> epoch: 71/1200, Loss:0.1253, l: 941
# Entering Epoch:  72
#
# ======> epoch: 72/1200, Loss:0.2215, l: 941
# Entering Epoch:  73
#
# ======> epoch: 73/1200, Loss:0.1478, l: 941
# Entering Epoch:  74
#
# ======> epoch: 74/1200, Loss:0.0948, l: 941
# Entering Epoch:  75
#
# ======> epoch: 75/1200, Loss:0.1320, l: 941
# Entering Epoch:  76
#
# ======> epoch: 76/1200, Loss:0.1475, l: 941
# Entering Epoch:  77
#
# ======> epoch: 77/1200, Loss:0.1636, l: 941
# Entering Epoch:  78
#
# ======> epoch: 78/1200, Loss:0.0736, l: 941
# Entering Epoch:  79
#
# ======> epoch: 79/1200, Loss:0.1371, l: 941
# Entering Epoch:  80
#
# ======> epoch: 80/1200, Loss:0.1363, l: 941
# Entering Epoch:  81
# Tue Jul  7 14:44:22 2020

# %%
data = loader.loader(None).generator()

# %%
plt.figure(figsize=(6,15))

for i, (id,x,y) in enumerate(data,1):
    plt.subplot(3,1,i)
    b1 = x.numpy()[0,0,:]
    b2 = dn(x)[1].detach().numpy()[0,0,:]
    plt.plot(b1)
    plt.plot(b2)
    print(norm(b1),norm(b2))
    
    if not i % 3:
        break
# Out:
# 1.9266241788864136 0.5372263789176941
# 1.5141241550445557 0.33558961749076843
# 1.5041179656982422 0.22074389457702637

# %%
from scipy.linalg import norm
